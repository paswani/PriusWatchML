# %% [markdown]
# Clone PriusWatchML Repo

# %%
# !git clone -l -s https://cchighman:8059ebaec5cf2f09c29b55d649f7e688d3b24bd8@github.com/cchighman/PriusWatchML.git cloned-repo
# %cd cloned-repo
# Out:
# Cloning into 'cloned-repo'...
# warning: --local is ignored
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 224 (delta 8), reused 0 (delta 0), pack-reused 208
# Receiving objects: 100% (224/224), 1012.69 KiB | 2.64 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# /content/cloned-repo

# %% [markdown]
# Install Modules

# %%
# !pip install dhash
# !pip install timeloop
# Out:
# Collecting dhash
#   Downloading https://files.pythonhosted.org/packages/3d/98/621b5dffc1d47135377ceeebd173f0daaa3e4c993a4dfd5cc0d63a3ffdbd/dhash-1.3.tar.gz
# Building wheels for collected packages: dhash
#   Building wheel for dhash (setup.py) ... done
#   Created wheel for dhash: filename=dhash-1.3-cp36-none-any.whl size=7274 sha256=03b6b23cf47d7f654edcce2fa00cada5c7bfd54fc21fc5a43a2288f154cb5060
#   Stored in directory: /root/.cache/pip/wheels/a4/cb/88/d7cf61a1ac52042d59cc0c7a130c04b1541dfd439570c6ea41
# Successfully built dhash
# Installing collected packages: dhash
# Successfully installed dhash-1.3
# Collecting timeloop
#   Downloading https://files.pythonhosted.org/packages/6a/95/3e39ee32f15a8e9dea46bb52300611a5351964eeaa393bafb0d738e90ce0/timeloop-1.0.2.tar.gz
# Building wheels for collected packages: timeloop
#   Building wheel for timeloop (setup.py) ... done
#   Created wheel for timeloop: filename=timeloop-1.0.2-cp36-none-any.whl size=3721 sha256=5d7553c242f41c6fc46bd308b861cece55794acaeb7d3ba5796d9f17320562f3
#   Stored in directory: /root/.cache/pip/wheels/70/e7/0e/d125f034638a6f46b47b419e51b9c5885f23c054072579d791
# Successfully built timeloop
# Installing collected packages: timeloop
# Successfully installed timeloop-1.0.2

# %% [markdown]
# Save Images to Drive

# %%
# !python watch_cameras.py --path "../drive/My Drive/frames_wash/" --cams seattle_cams2.json --timer 60
# Out:
# Streaming output truncated to the last 5000 lines.
# Putting hash d6061ae49831e58bff0e3ae49830c5ff for cam 9624 in cache.
# Putting hash 31bffed832e48d5967fff49872e604ff for cam 1061 in cache.
# Checking Duplicate: 9625
# Checking Duplicate: 1062
# Putting hash e44ecae1b09ec7f10130fecf63380cff for cam 9625 in cache.
# Checking Duplicate: 9626
# Putting hash 48c436f8e0a295a6001ffcf0e0e000ff for cam 1062 in cache.
# Putting hash ce8db9e3ce1e36e0001df9e38c1836ff for cam 9626 in cache.
# Checking Duplicate: 1064
# 202051_1-31_58_1064.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1366
# Putting hash d8e8e4f0747bfc7680180f83a43289ff for cam 1366 in cache.
# Checking Duplicate: 1065
# 202051_1-31_58_1065.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1367
# Putting hash e39efce8c8d0b0908f7ff0e0e90f60b1 for cam 1367 in cache.
# Checking Duplicate: 1067
# Putting hash b7feac98b840c0900ff6fc96387ec6b3 for cam 1067 in cache.
# Checking Duplicate: 1368
# Checking Duplicate: 1068
# Putting hash 20a8b2b9bc1e9e3f05d906e7840083ff for cam 1368 in cache.
# Putting hash 8f0eec8223c99020fcffe0803e4880ff for cam 1068 in cache.
# Checking Duplicate: 9627
# Checking Duplicate: 1070
# 202051_1-31_59_9627.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1069
# 202051_1-31_58_1070.jpg is a duplicate image.  Removing.
# Putting hash 580836f6ec9864c800013bf6ee9a64ff for cam 1069 in cache.
# Checking Duplicate: 1370
# Checking Duplicate: 1369
# 202051_1-31_58_1369.jpg is a duplicate image.  Removing.
# Putting hash 68ecac0c66c6c687f7fb810161fcc0ff for cam 1370 in cache.
# Checking Duplicate: 1371
# cannot identify image file <_io.BytesIO object at 0x7ff2f5c7a258>
# Checking Duplicate: 9628
# 202051_1-31_59_9628.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1071
# Putting hash bfbf86ce3874cc88f8e1279e1860c0ff for cam 1071 in cache.
# Checking Duplicate: 9083
# Checking Duplicate: 9629
# Putting hash 5a7873b1608625251f0040b0e3d400ff for cam 9629 in cache.
# Putting hash de78889cba0f0d5cdc400019e03e01ff for cam 9083 in cache.
# Checking Duplicate: 1072
# 202051_1-31_59_1072.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9084
# 202051_1-31_59_9084.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1376
# 202051_1-31_59_1376.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1073
# Putting hash 587083d5fcf7fcdeff40009fc12601ff for cam 1073 in cache.
# Checking Duplicate: 1374
# 202051_1-31_59_1374.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1375
# Putting hash d8dedefeecd8b0e0010000f6ccd830ff for cam 1375 in cache.
# Checking Duplicate: 1196
# Putting hash 597c3878c0204999ff0000f0c62749ff for cam 1196 in cache.
# Checking Duplicate: 9631
# 202051_1-31_59_9631.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9632
# Putting hash 585202c0f0c69b6bf80006ffc10436ff for cam 9632 in cache.
# Checking Duplicate: 9633
# Checking Duplicate: 1377
# 202051_1-31_59_1377.jpg is a duplicate image.  Removing.
# 202051_1-31_59_9633.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1379
# Checking Duplicate: 9630
# Putting hash fefef8e0e1819192fefef0e0c40000ff for cam 1379 in cache.
# Putting hash 7830deec82ce9a760000fffd070c19ff for cam 9630 in cache.
# Checking Duplicate: 1380
# Putting hash 5e4e3cf0cc0c9810000c7df3d00c08ff for cam 1380 in cache.
# Checking Duplicate: 1075
# Putting hash 9c9c70e09820448880b9ffc400204cff for cam 1075 in cache.
# Checking Duplicate: 9691
# Putting hash 79b1e4c6a6c78606007be18020c280ff for cam 9691 in cache.
# Checking Duplicate: 1076
# Putting hash 5a3c1ce08081a001870078e1001e01ff for cam 1076 in cache.
# Checking Duplicate: 9634
# Putting hash a6a083c120000080ffffff0f000000ff for cam 9634 in cache.
# Checking Duplicate: 1078
# Putting hash a44e22334f3ebcf0ff5c0000fffe08ff for cam 1078 in cache.
# Checking Duplicate: 1381
# Checking Duplicate: 1077
# Putting hash 76d8939193e6c8c8fff8003bff6600ff for cam 1381 in cache.
# Checking Duplicate: 1079
# Checking Duplicate: 9635
# Putting hash 5a7000b8d8b064e4de0000ffc93266ff for cam 1077 in cache.
# Putting hash ce1cbcc030a1499380fef08031a448ff for cam 1079 in cache.
# Checking Duplicate: 1382
# 202051_1-32_0_9635.jpg is a duplicate image.  Removing.
# 202051_1-32_0_1382.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1080
# Checking Duplicate: 1383
# 202051_1-32_0_1080.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1082
# 202051_1-32_0_1383.jpg is a duplicate image.  Removing.
# Putting hash bfcffcf8e4e881d020dffcf0800008ff for cam 1082 in cache.
# Checking Duplicate: 1384
# 202051_1-32_0_1384.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9636
# Checking Duplicate: 1385
# Checking Duplicate: 1388
# 202051_1-32_0_9636.jpg is a duplicate image.  Removing.
# 202051_1-32_0_1388.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1387
# Putting hash b8a8d8f8f0c0a4c8e0261ffbf1d004ff for cam 1385 in cache.
# 202051_1-32_0_1387.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1389
# 202051_1-32_0_1389.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9085
# 202051_1-32_0_9085.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1085
# 202051_1-32_0_1085.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1084
# 202051_1-32_0_1084.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1390
# Checking Duplicate: 1393
# Checking Duplicate: 1086
# Putting hash a89878d9a142d392023f60d12068c0ff for cam 1390 in cache.
# Putting hash 16eedc7ce8d09444102ebcf0e98210ff for cam 1086 in cache.
# Putting hash 5a69a1b8f020e0c81400007dc13060ff for cam 1393 in cache.
# Checking Duplicate: 1309
# Checking Duplicate: 1310
# Checking Duplicate: 9273
# Checking Duplicate: 1313
# Checking Duplicate: 1392
# 202051_1-32_0_1313.jpg is a duplicate image.  Removing.
# 202051_1-32_0_9273.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1087
# 202051_1-32_0_1310.jpg is a duplicate image.  Removing.
# 202051_1-32_0_1087.jpg is a duplicate image.  Removing.
# Putting hash 5e4eaeb4888440a0f3ff0000fbfcdfff for cam 1309 in cache.
# Putting hash 1e8638d8e040c4c4001e7cf0800061ff for cam 1392 in cache.
# Checking Duplicate: 9504
# Checking Duplicate: 9503
# Putting hash 589287e19967bfbf40001cc003430cff for cam 9503 in cache.
# Putting hash b2fafef6ccb8b2b40002ffe0ccf880ff for cam 9504 in cache.
# Checking Duplicate: 1394
# Putting hash 64b7fefcda62c48c003ffee49862c0ff for cam 1394 in cache.
# Checking Duplicate: 1012
# Putting hash 7e72d2c2f0e0fef0ff60000e9341e8ff for cam 1012 in cache.
# Checking Duplicate: 1396
# Checking Duplicate: 9505
# Checking Duplicate: 1399
# Putting hash 72528080c082514440000003008c13ff for cam 9505 in cache.
# Putting hash 52f0dbf3ecf3f9b43f00001f088643ff for cam 1399 in cache.
# Putting hash 50769efc9830e09801003efc9870c0ff for cam 1396 in cache.
# Checking Duplicate: 1013
# 202051_1-32_1_1013.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1398
# Checking Duplicate: 1395
# Checking Duplicate: 1014
# Checking Duplicate: 1397
# Putting hash 76f1c0d8e6f16cfa1c00009fcc034dff for cam 1398 in cache.
# Putting hash 5ab4f1c88ec6c2830000f7c1b879c1ff for cam 1395 in cache.
# Putting hash eee0d0f270c0a100fc0000f870c0a0ff for cam 1014 in cache.
# Putting hash e7a7fedc70c09080001ffe9870c080ff for cam 1397 in cache.
# Checking Duplicate: 1015
# Putting hash 524c38f0c090111100003ce0800203ff for cam 1015 in cache.
# Checking Duplicate: 1401
# 202051_1-32_1_1401.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1400
# Putting hash 039706807498c4e3ffff7e0f44309cff for cam 1400 in cache.
# Checking Duplicate: 1016
# Checking Duplicate: 1018
# Checking Duplicate: 1017
# Putting hash 527484008084d0e8fe00007f1f2c17ff for cam 1016 in cache.
# Checking Duplicate: 9507
# Putting hash a68e5b73636060acffff98a67e2040ff for cam 1018 in cache.
# Putting hash 527c4968e4e6e7c706001bfbf9e4c23f for cam 1017 in cache.
# 202051_1-32_1_9507.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9054
# 202051_1-32_1_9054.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9274
# Putting hash 585888c0d020808000003cc0826380ff for cam 9274 in cache.
# Checking Duplicate: 1402
# Checking Duplicate: 1020
# Putting hash f3fcc090d28484807ff8800080f01cff for cam 1402 in cache.
# Putting hash fce0a2d49c32468e300007c6996040ff for cam 1020 in cache.
# Checking Duplicate: 9510
# Checking Duplicate: 1021
# Checking Duplicate: 9509
# Checking Duplicate: 9511
# Checking Duplicate: 9508
# Putting hash f8fcbcfcf0e0d88800003ffcfe6cc0ff for cam 9509 in cache.
# Putting hash 7a6888fcfcbc6c80c400017ec030ecff for cam 1021 in cache.
# 202051_1-32_2_9508.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1023
# Checking Duplicate: 1022
# Checking Duplicate: 1403
# Putting hash 5f796160d1909898043c0060c6ffdfff for cam 9511 in cache.
# Putting hash f67e80638690e4f1fff800436e330cff for cam 9510 in cache.
# Putting hash dc5e07f0d89f2e2780001fe7c39000ff for cam 1022 in cache.
# Putting hash dafbe4a4e0f0f0b81f00003c076f85ff for cam 1403 in cache.
# Putting hash 5050a7be78e8d0e800000fbc78e886ff for cam 1023 in cache.
# Checking Duplicate: 9512
# Checking Duplicate: 9513
# Checking Duplicate: 9514
# 202051_1-32_2_9513.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1026
# Putting hash 5070ecf8b0e0e0b000000c1830f0ccff for cam 9512 in cache.
# Putting hash 08101092000041003ff9000000ff00ff for cam 1026 in cache.
# Checking Duplicate: 9056
# 202051_1-32_2_9056.jpg is a duplicate image.  Removing.
# Putting hash b2e6bae69ef4ecf4000f33461a70ccff for cam 9514 in cache.
# Checking Duplicate: 9516
# Checking Duplicate: 9055
# Putting hash 507c6e72e0ac2cec07000876c3f723ff for cam 9516 in cache.
# Checking Duplicate: 1024
# Checking Duplicate: 9515
# 202051_1-32_2_9515.jpg is a duplicate image.  Removing.
# Putting hash 57f2f0e8ccc68383080077e3e9c400ff for cam 9055 in cache.
# Putting hash 5070317058c88c8c800007ff63c3b8ff for cam 1024 in cache.
# Checking Duplicate: 9355
# Checking Duplicate: 9356
# Checking Duplicate: 1025
# Putting hash f6fae2fefcf484a8800007cc30e080ff for cam 9355 in cache.
# Putting hash 58439938f121c99900061e38d460c0ff for cam 9356 in cache.
# 202051_1-32_2_1025.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9057
# Checking Duplicate: 9519
# 202051_1-32_2_9519.jpg is a duplicate image.  Removing.
# Putting hash 4ecc7d7858386af2008eff68103040ff for cam 9057 in cache.
# Checking Duplicate: 1027
# Checking Duplicate: 9518
# Putting hash 5a10c6cde1d9a831c00016df0ed388ff for cam 1027 in cache.
# Checking Duplicate: 9517
# Checking Duplicate: 1028
# Putting hash 2e743120cd9c8ed7bc8c7322cfff3cff for cam 9518 in cache.
# Checking Duplicate: 9520
# 202051_1-32_2_9517.jpg is a duplicate image.  Removing.
# 202051_1-32_3_9520.jpg is a duplicate image.  Removing.
# Putting hash 5a583c989cf6f3d28f0020633ffcedff for cam 1028 in cache.
# Checking Duplicate: 9521
# Putting hash 54f4f8b8e8cc86871f0000a063c900ff for cam 9521 in cache.
# Checking Duplicate: 9522
# Checking Duplicate: 9523
# Putting hash ccd0c0c860e0e0f09f10913a4d070dff for cam 9522 in cache.
# Putting hash 8c8c1c1c3c6cec78ff8fff1dffec08ff for cam 9523 in cache.
# Checking Duplicate: 9528
# Putting hash 18303b3b733f3e3f1fc1ff3b030f00ff for cam 9528 in cache.
# Checking Duplicate: 9526
# Checking Duplicate: 9524
# Putting hash d3f3e6be6de6e2f0030306a03f4c0eff for cam 9526 in cache.
# Putting hash a094d080c0c0e094ff07f8bf00ff00ff for cam 9524 in cache.
# Checking Duplicate: 9525
# Checking Duplicate: 9527
# 202051_1-32_3_9527.jpg is a duplicate image.  Removing.
# Putting hash e0e0f1b2c3808080000001f7ffff7fff for cam 9525 in cache.
# Checking Duplicate: 9535
# Checking Duplicate: 9530
# Putting hash 82c840b28fafafe6bfb843e7ff7f1fff for cam 9530 in cache.
# Putting hash 54f0e030b0f0f8f11e0000207786daff for cam 9535 in cache.
# Checking Duplicate: 9531
# Checking Duplicate: 9529
# Checking Duplicate: 9532
# Checking Duplicate: 9533
# 202051_1-32_3_9529.jpg is a duplicate image.  Removing.
# 202051_1-32_3_9532.jpg is a duplicate image.  Removing.
# Putting hash a0a4e0a020000381ffffff03000000ff for cam 9531 in cache.
# Putting hash a4a404404220a020ffe7ff1f1f0a00ff for cam 9533 in cache.
# Checking Duplicate: 1029
# Checking Duplicate: 9534
# 202051_1-32_3_1029.jpg is a duplicate image.  Removing.
# 202051_1-32_3_9534.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9365
# Checking Duplicate: 9539
# Checking Duplicate: 9537
# Checking Duplicate: 9536
# Checking Duplicate: 9366
# 202051_1-32_3_9366.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9538
# Checking Duplicate: 9367
# Checking Duplicate: 1030
# 202051_1-32_3_9537.jpg is a duplicate image.  Removing.
# 202051_1-32_3_9539.jpg is a duplicate image.  Removing.
# 202051_1-32_3_9538.jpg is a duplicate image.  Removing.
# 202051_1-32_3_1030.jpg is a duplicate image.  Removing.
# Putting hash d4778ba4c68f0d8f80c0fb23e48e4fff for cam 9365 in cache.
# Putting hash 00000b038081c0c0f887fffffcbf0f03 for cam 9367 in cache.
# Putting hash 5cd0c1cfe188beb6000000d8c70b9eff for cam 9536 in cache.
# Checking Duplicate: 9540
# Putting hash 5c480210f88ec7f1d0c0083fc0380cff for cam 9540 in cache.
# Checking Duplicate: 9541
# Checking Duplicate: 9299
# Putting hash 4070d0bce6d2c1a53f07033be09202ff for cam 9541 in cache.
# Checking Duplicate: 9542
# Checking Duplicate: 9543
# Checking Duplicate: 1031
# Putting hash 5070e784a4286c980070ef0c070060ff for cam 9299 in cache.
# Putting hash a1e0e0121c72d29effffeb061860c0ff for cam 9542 in cache.
# Putting hash a68389d834c68b0bffff8f9b31cf807f for cam 9543 in cache.
# Putting hash 31f15c5ad99c9e0e3683ff60c1d198ff for cam 1031 in cache.
# Checking Duplicate: 9544
# 202051_1-32_4_9544.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9401
# Checking Duplicate: 1406
# Checking Duplicate: 9545
# Checking Duplicate: 1032
# 202051_1-32_4_9401.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9547
# 202051_1-32_4_9545.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9546
# Checking Duplicate: 9060
# Putting hash 5e762070f4f2eae000002febcd00e0ff for cam 1032 in cache.
# Checking Duplicate: 1033
# Putting hash a692fffefefdfefeff077fffe4f000fe for cam 9547 in cache.
# Putting hash 5e6b6b6f7ffbfcf8149000006efeffff for cam 1406 in cache.
# Putting hash f0e0e0b4969646560067df01c0b500ff for cam 9546 in cache.
# Putting hash ffbcfcdab276e6a6003fe5c8927040ff for cam 9060 in cache.
# Putting hash 58d8e9e86c6c7c7000003306c9df38ff for cam 1033 in cache.
# Checking Duplicate: 9400
# 202051_1-32_4_9400.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1034
# Putting hash 76769800a0f8bed783f400003f0120ff for cam 1034 in cache.
# Checking Duplicate: 9548
# 202051_1-32_4_9548.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9549
# Putting hash 55358182c8e0e183db7000003fffc3ff for cam 9549 in cache.
# Checking Duplicate: 1409
# Checking Duplicate: 9550
# Checking Duplicate: 1035
# Putting hash 757db2b06cecc686870000b3e1e140ff for cam 1035 in cache.
# Putting hash 727ebab0628323830000feb0608104ff for cam 1409 in cache.
# Putting hash 76ecdad2d16366966300c0fe033be7ff for cam 9550 in cache.
# Checking Duplicate: 1036
# Checking Duplicate: 9553
# Checking Duplicate: 1411
# Checking Duplicate: 9551
# Checking Duplicate: 9552
# Checking Duplicate: 1038
# Putting hash f8fcec79eab644cc0000fff9f9b264ff for cam 1036 in cache.
# 202051_1-32_5_9551.jpg is a duplicate image.  Removing.
# Putting hash 88dcfcd8a4d080a00118e0d024d200ff for cam 9553 in cache.
# Putting hash 5aeeaeecd8e0c0800000fffcd0e080ff for cam 9552 in cache.
# Putting hash f8fefefcdcd8e0808390fce01c30e0ff for cam 1038 in cache.
# Checking Duplicate: 9554
# Checking Duplicate: 9555
# 202051_1-32_5_1411.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1037
# Putting hash d2bcbcd8b0e4a6260600fdf930c380ff for cam 9554 in cache.
# Putting hash 61e89828ca922222ffc39025d89800ff for cam 1037 in cache.
# Checking Duplicate: 1039
# Putting hash 1f3e69ab9a8a9a387ffe60e1f70f08ff for cam 9555 in cache.
# Putting hash f0baf3f1c4a4cccc0113fee381a202ff for cam 1039 in cache.
# Checking Duplicate: 9556
# Checking Duplicate: 9557
# Checking Duplicate: 1338
# Checking Duplicate: 1040
# Checking Duplicate: 9447
# Putting hash faded6defaf4cc980000061cfae2c4ff for cam 9557 in cache.
# Putting hash b8f8d8b46cc89a9230f9c93061c988ff for cam 9556 in cache.
# Putting hash 525a93eccc8e9919000012a3c5cc00ff for cam 9447 in cache.
# Putting hash 50fc8c9c32e0e0e200009ff978fcc0ff for cam 1338 in cache.
# Putting hash a7a7d71fbeb8f0f6ffffeffffc0001ff for cam 1040 in cache.
# Checking Duplicate: 9559
# Checking Duplicate: 9558
# Putting hash 5b70e0c2c9e6e3ecdf0000f6092c02ff for cam 9559 in cache.
# Checking Duplicate: 1042
# 202051_1-32_5_1042.jpg is a duplicate image.  Removing.
# Putting hash d2d0dcc0e0e0b0d80003389f0fc3a0ff for cam 9558 in cache.
# Checking Duplicate: 1412
# Checking Duplicate: 1413
# Checking Duplicate: 1043
# Checking Duplicate: 1045
# Checking Duplicate: 1044
# Checking Duplicate: 1046
# Checking Duplicate: 9069
# Putting hash 8ab3168687885c8088ffff00de0600ff for cam 1412 in cache.
# Checking Duplicate: 9068
# 202051_1-32_5_1045.jpg is a duplicate image.  Removing.
# Putting hash e4d8d8e8c89c3c2c6e0031e7cb0031ff for cam 1044 in cache.
# 202051_1-32_5_9068.jpg is a duplicate image.  Removing.
# Putting hash 5858b2f0e8d8c8883f000077e3c100ff for cam 1043 in cache.
# Putting hash 30f938b1b8ceeefe200078e7b3dbc8ff for cam 1046 in cache.
# Putting hash 163ce70c76c409301e79c61cf28418ff for cam 9069 in cache.
# Putting hash 0e9efce4c99892b66fbefce0cc0913ff for cam 1413 in cache.
# Checking Duplicate: 1047
# 202051_1-32_6_1047.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1416
# Putting hash e0f4bc766c18943a0000bff4e84b01ff for cam 1416 in cache.
# Checking Duplicate: 1048
# Checking Duplicate: 9070
# Putting hash d2da327afcb6eee600c8377fd0837eff for cam 1048 in cache.
# Checking Duplicate: 1420
# Putting hash a8c0823eb66581933bff8f3fb840c9ff for cam 9070 in cache.
# Putting hash 5278b8f45efcfcfc060011871c7feeff for cam 1420 in cache.
# Checking Duplicate: 1422
# 202051_1-32_6_1422.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1419
# 202051_1-32_6_1419.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1417
# Checking Duplicate: 1421
# Putting hash dc9ebab83cf8f8b800409f0020f980ff for cam 1417 in cache.
# Putting hash 52d8ded6bcfaf4ec0700e09f3d72f4ff for cam 1421 in cache.
# Checking Duplicate: 1418
# Checking Duplicate: 1424
# Checking Duplicate: 1425
# Checking Duplicate: 1423
# Checking Duplicate: 1426
# Putting hash c2b6faeef2f9f3be07047b083fc003ff for cam 1418 in cache.
# 202051_1-32_6_1424.jpg is a duplicate image.  Removing.
# Putting hash d3c080f0b261298bf0f0000896e361ff for cam 1426 in cache.
# Putting hash 5056c0a69198989d1000dbcc279101ff for cam 1425 in cache.
# Putting hash 4040c1989c94969b007eefc3c10100ff for cam 1423 in cache.
# Checking Duplicate: 1427
# Checking Duplicate: 1428
# Checking Duplicate: 1429
# Checking Duplicate: 1430
# Checking Duplicate: 9071
# Putting hash 7658f8e03232b2230000fd810170b0ff for cam 1429 in cache.
# Putting hash 5459f9e988d991b0001ff0e539c080ff for cam 1428 in cache.
# Putting hash 4060b8989b3a5c9c1f43a700020200ff for cam 1427 in cache.
# Putting hash 50529ebcd8b0e20400013ffcd830c2ff for cam 1430 in cache.
# Putting hash 41879f7acc9a66cc010f3ff3cd3962ff for cam 9071 in cache.
# Checking Duplicate: 9560
# Putting hash f5bc7ae4c89c64ccc71d7ae4c89e24ff for cam 9560 in cache.
# Checking Duplicate: 1431
# Putting hash 4b839ffce471e28a00077ffacc70c0ff for cam 1431 in cache.
# Checking Duplicate: 9237
# 202051_1-32_7_9237.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9275
# Putting hash d010c0e0e0e86c66ff001fdf051301ff for cam 9275 in cache.
# Checking Duplicate: 9752
# Putting hash e2f2e2db5b9d9abc0007e7e2420500ff for cam 9752 in cache.
# Checking Duplicate: 9270
# 202051_1-32_7_9270.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9563
# 202051_1-32_7_9563.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9276
# Putting hash 5878bc74c4946cc80000bc70ca9404ff for cam 9276 in cache.
# Checking Duplicate: 9562
# Checking Duplicate: 9269
# 202051_1-32_7_9562.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9561
# Checking Duplicate: 9235
# Putting hash 567531513199cca290002098673018ff for cam 9269 in cache.
# Putting hash d85ccc0c689930608000c01ce49820ff for cam 9561 in cache.
# Putting hash 5e70b0e0002048c95c0023ff002600ff for cam 9235 in cache.
# Checking Duplicate: 9236
# 202051_1-32_7_9236.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9238
# Putting hash 5c58187bd030c090fe000078c22240ff for cam 9238 in cache.
# Checking Duplicate: 9345
# 202051_1-32_7_9345.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9271
# 202051_1-32_7_9271.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9344
# Putting hash 5c5dd89060d0a0a20000c0bf6bd000ff for cam 9344 in cache.
# Checking Duplicate: 1433
# Putting hash 524c82d0cefab2dcff0000ff04ff66ff for cam 1433 in cache.
# Checking Duplicate: 9240
# Putting hash 3e1e6060d8cc969eff380066f3c9ccff for cam 9240 in cache.
# Checking Duplicate: 5020
# Putting hash de60a798e3861d390000ff38e38e38ff for cam 5020 in cache.
# Checking Duplicate: 9239
# Checking Duplicate: 9564
# Putting hash fe7ec2603098ee268020becfe10000ff for cam 9239 in cache.
# 202051_1-32_7_9564.jpg is a duplicate image.  Removing.
# Checking Duplicate: 5021
# Checking Duplicate: 8104
# Checking Duplicate: 9568
# Putting hash 74d4e0e6f1fcde9f00001f0c032100ff for cam 5021 in cache.
# Putting hash b6d0882c269383a13ec7030160001cff for cam 8104 in cache.
# Checking Duplicate: 8105
# Putting hash e62f0aec19e2c60e00ffffcc39e2847f for cam 9568 in cache.
# Putting hash 98e9d236c48e1616ff299870c00000ff for cam 8105 in cache.
# Checking Duplicate: 1316
# 202051_1-32_8_1316.jpg is a duplicate image.  Removing.
# Checking Duplicate: 8059
# Putting hash 4664f0706a6eced0000cff93000080ff for cam 8059 in cache.
# Checking Duplicate: 9383
# Checking Duplicate: 5018
# Checking Duplicate: 8060
# Putting hash 5e5c2424ce3eeefcbff800030f3e64ff for cam 9383 in cache.
# Checking Duplicate: 1054
# Putting hash 54c4c8f8c89818ba00208e60c10108ff for cam 5018 in cache.
# Putting hash 7261a9f1e140e4a7b80008fb0243c1ff for cam 8060 in cache.
# Putting hash fef8f8fcfcf0c890ff0003fef860c83f for cam 1054 in cache.
# Checking Duplicate: 1322
# Putting hash 77eebcf0e1a34286ff8e18f0e081c3ff for cam 1322 in cache.
# Checking Duplicate: 1526
# 202051_1-32_8_1526.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1329
# Checking Duplicate: 9336
# Putting hash 565aa632303a3d36ffc0000e071201ff for cam 1329 in cache.
# Putting hash f5f0f4e4cc1c3830ffff32e08f1818ff for cam 9336 in cache.
# Checking Duplicate: 9337
# Putting hash 564448197cd63262c000031ff99e30ff for cam 9337 in cache.
# Checking Duplicate: 1323
# Putting hash d05f9bbad8b230310005fe3a5bdf10ff for cam 1323 in cache.
# Checking Duplicate: 9324
# Putting hash 547202a41832e082ff0000fc1872c0ff for cam 9324 in cache.
# Checking Duplicate: 1326
# Checking Duplicate: 1324
# Checking Duplicate: 1325
# Checking Duplicate: 1328
# Putting hash cc9834e8d89131610c1b77ecc89830ff for cam 1324 in cache.
# Putting hash bebed6e4cc9c387827f8f2664c9c38ff for cam 1326 in cache.
# Checking Duplicate: 9347
# Putting hash 8c1c28da923167ce041f7c489a3163ff for cam 1325 in cache.
# Putting hash d2768002f2e4d496fbf40000f7e7c1ff for cam 1328 in cache.
# 202051_1-32_8_9347.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9569
# Checking Duplicate: 9325
# Checking Duplicate: 9323
# 202051_1-32_8_9323.jpg is a duplicate image.  Removing.
# 202051_1-32_8_9325.jpg is a duplicate image.  Removing.
# Putting hash 507391809a98d0c980003ea77f3e01ff for cam 9569 in cache.
# Checking Duplicate: 9348
# Putting hash 7a6a72f0a489c3b700007ff0e11903ff for cam 9348 in cache.
# Checking Duplicate: 9326
# 202051_1-32_8_9326.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9349
# Putting hash 4444c6c0f0e6b6db0010fc1f030304ff for cam 9349 in cache.
# Checking Duplicate: 9329
# Putting hash d4dcc0e86e26b33947380081800804ff for cam 9329 in cache.
# Checking Duplicate: 9327
# Putting hash 3a1a7cdc34e8b9710010fed830cc99ff for cam 9327 in cache.
# Checking Duplicate: 9328
# Putting hash d27e60e4e2e0f3f1bf3e0000ff430cff for cam 9328 in cache.
# Checking Duplicate: 9331
# Putting hash de5c4cf4d838f0f282001be4d818e0ff for cam 9331 in cache.
# Checking Duplicate: 9330
# Checking Duplicate: 9335
# 202051_1-32_8_9330.jpg is a duplicate image.  Removing.
# 202051_1-32_9_9335.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9332
# Checking Duplicate: 9333
# 202051_1-32_8_9332.jpg is a duplicate image.  Removing.
# Putting hash 58f4f8f998b060c0521c000199bb62ff for cam 9333 in cache.
# Checking Duplicate: 1330
# Putting hash 545ec2e4e29078d88100063dee0000ff for cam 1330 in cache.
# Checking Duplicate: 9334
# 202051_1-32_9_9334.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9072
# 202051_1-32_9_9072.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1055
# Checking Duplicate: 1056
# Putting hash 5c5e8ac0c8e6f23200003c1f1b0ec0ff for cam 1056 in cache.
# Putting hash 565cece2b0b1b8383700004f409703ff for cam 1055 in cache.
# Checking Duplicate: 9580
# Checking Duplicate: 1210
# 202051_1-32_9_9580.jpg is a duplicate image.  Removing.
# 202051_1-32_9_1210.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1057
# 202051_1-32_9_1057.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1435
# Putting hash a2a28da6e383d090ffffdf3840bf4eff for cam 1435 in cache.
# Checking Duplicate: 1281
# Checking Duplicate: 9581
# Putting hash 54442d9cc4b1382c008061381c87c3ff for cam 1281 in cache.
# Putting hash feff7e1c3cfcf8f89cb0c31c30fef8ff for cam 9581 in cache.
# Checking Duplicate: 1058
# 202051_1-32_9_1058.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1436
# 202051_1-32_9_1436.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1434
# Putting hash 70f6368c5c1818c200c0e60efcf83bff for cam 1434 in cache.
# Checking Duplicate: 1088
# Putting hash 5a10c6cde1d9a831c00016df0ed388ff for cam 1088 in cache.
# Checking Duplicate: 9582
# 202051_1-32_9_9582.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1437
# Putting hash a1a3c0c8cc4c4d6dffff27018fbad27d for cam 1437 in cache.
# Checking Duplicate: 9073
# 202051_1-32_9_9073.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1089
# Checking Duplicate: 9583
# Putting hash c283e4980878289c800effff034100ff for cam 9583 in cache.
# Putting hash b3b6f6f2d3f1f0fefb3ffc657e0203ff for cam 1089 in cache.
# Checking Duplicate: 9584
# 202051_1-32_9_9584.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9585
# 202051_1-32_9_9585.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1438
# Putting hash 30fcdc78e4c890903fff9870c08000ff for cam 1438 in cache.
# Checking Duplicate: 1090
# Putting hash d0f28e1a78f2e0d800c30c1a70f2c0ff for cam 1090 in cache.
# Checking Duplicate: 9586
# 202051_1-32_9_9586.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1091
# 202051_1-32_10_1091.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9587
# Checking Duplicate: 1444
# Putting hash 5c59e03098c4e1f000008e67311c07ff for cam 9587 in cache.
# Putting hash 9cc670ecb4d5b424001fffe22851b0ff for cam 1444 in cache.
# Checking Duplicate: 9757
# Checking Duplicate: 1445
# Checking Duplicate: 9588
# Putting hash 4908a1d0485413490010ef371b8506ff for cam 9757 in cache.
# Putting hash 81481c7cf9cbc3c3ffff0000f1f9c9ff for cam 9588 in cache.
# Putting hash 879bb6e6dedede9f043b3fe6fee980ff for cam 1445 in cache.
# Checking Duplicate: 9590
# 202051_1-32_10_9590.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1448
# Checking Duplicate: 1446
# Putting hash 58488040c494862600003e7fcb9d00ff for cam 1448 in cache.
# Putting hash 78d0e0e8c957b3b740003467dbcc02ff for cam 1446 in cache.
# Checking Duplicate: 9252
# cannot identify image file <_io.BytesIO object at 0x7ff2f6809d00>
# Checking Duplicate: 9589
# Putting hash c6a62898889874e084fcfc000f1830ff for cam 9589 in cache.
# Checking Duplicate: 1449
# Putting hash 58c8e1b0105898980000ff8d064381ff for cam 1449 in cache.
# Checking Duplicate: 9405
# 202051_1-32_10_9405.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9593
# Checking Duplicate: 9053
# Putting hash 5a5cfcbae4cd39700200f81024cc10ff for cam 9593 in cache.
# Putting hash 5ad8fcfcb898b0d00f00c0fe609000ff for cam 9053 in cache.
# Checking Duplicate: 9591
# Putting hash 5a18b0c831c890b000dcf008778101ff for cam 9591 in cache.
# Checking Duplicate: 1092
# Checking Duplicate: 1450
# 202051_1-32_10_1092.jpg is a duplicate image.  Removing.
# Putting hash 505086c0c0c0486cc0003cf89e8713ff for cam 1450 in cache.
# Checking Duplicate: 1096
# 202051_1-32_10_1096.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9592
# Putting hash d258f8d83c6cee8e0000e08320e000ff for cam 9592 in cache.
# Checking Duplicate: 1094
# 202051_1-32_10_1094.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1095
# 202051_1-32_10_1095.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1451
# 202051_1-32_10_1451.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1453
# Checking Duplicate: 1452
# 202051_1-32_10_1452.jpg is a duplicate image.  Removing.
# Putting hash 5e77a79cf8b8acb2000007bcf2ffc0ff for cam 1453 in cache.
# Checking Duplicate: 1296
# Putting hash f8f9a8b3b899dcec007b188e072318ff for cam 1296 in cache.
# Checking Duplicate: 1454
# Putting hash bdee66dcf8f0d89001034e3cf8e0d8bf for cam 1454 in cache.
# Checking Duplicate: 1455
# Putting hash c0c0220682c0e0f00080e07c3f1f07ff for cam 1455 in cache.
# Checking Duplicate: 9594
# Putting hash aeee7ac41872e0c0071df2cc1872e0ff for cam 9594 in cache.
# Checking Duplicate: 9277
# Putting hash 52c79c18b866e38037c70078ff78c0ff for cam 9277 in cache.
# Checking Duplicate: 1456
# 202051_1-32_11_1456.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9753
# Putting hash bcb8d8b870f2909bfd2cd8fbfdc7a3ff for cam 9753 in cache.
# Checking Duplicate: 9738
# Checking Duplicate: 9737
# Checking Duplicate: 9739
# Putting hash 24268cb830d4a44c0026cc397ad2a1ff for cam 9737 in cache.
# Putting hash f0423c38e4c8902500c7dc30e0c810ff for cam 9738 in cache.
# Putting hash e8d3f3ece6f9ecec2000c791040201ff for cam 9739 in cache.
# Checking Duplicate: 9406
# Checking Duplicate: 9740
# Checking Duplicate: 9407
# Putting hash f8dedfe1f8fcf6f5000038bf4b1090ff for cam 9406 in cache.
# Putting hash 90c9922242c2921277c99320604280ff for cam 9740 in cache.
# Checking Duplicate: 9736
# 202051_1-32_11_9407.jpg is a duplicate image.  Removing.
# Putting hash f3d9dc9697859b9bf4c381c400a500ff for cam 9736 in cache.
# Checking Duplicate: 9735
# 202051_1-32_11_9735.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1461
# Putting hash e000c7ca66516c6e8001ff9b0c0703ff for cam 1461 in cache.
# Checking Duplicate: 1177
# 202051_1-32_11_1177.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9734
# Putting hash f0f0b0e8c8cb8988000077e380c201ff for cam 9734 in cache.
# Checking Duplicate: 9733
# Putting hash e6f7b3eccccc8e0e0004ffe0e1c100ff for cam 9733 in cache.
# Checking Duplicate: 9732
# Checking Duplicate: 1178
# Putting hash 464cd8f0c9882828000ff9e0cc0503ff for cam 9732 in cache.
# Checking Duplicate: 1462
# Putting hash e2f1b1babd9cb6a6000007a07a8100ff for cam 1178 in cache.
# Putting hash 70b1b0e464844486007effe061a301ff for cam 1462 in cache.
# Checking Duplicate: 1463
# Checking Duplicate: 1179
# Checking Duplicate: 1465
# 202051_1-32_11_1179.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1180
# Putting hash 5a70932cbcf1e012ff00006ef8f5c9ff for cam 1465 in cache.
# Putting hash b793d3d9ccf6f2f9003604338bec06ff for cam 1180 in cache.
# Putting hash efbee6d8b4ecc8980010ec8820c40cff for cam 1463 in cache.
# Checking Duplicate: 1464
# Putting hash a47c74f41c8c64a8001ef081fafc00ff for cam 1464 in cache.
# Checking Duplicate: 1181
# 202051_1-32_11_1181.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1182
# Checking Duplicate: 9611
# Putting hash 121ef8f2e6c58d09071ff9f2e2c484ff for cam 1182 in cache.
# Putting hash febf83ccf2c40c3900000ffcf0860cff for cam 9611 in cache.
# Checking Duplicate: 1466
# Putting hash 279ffce28624cccc071ef8e283760cff for cam 1466 in cache.
# Checking Duplicate: 9612
# Putting hash 9df9c40c6cc991b93cf1821964ced0ff for cam 9612 in cache.
# Checking Duplicate: 1183
# Putting hash 31bffed832e48d5967fff49872e604ff for cam 1183 in cache.
# Checking Duplicate: 9613
# Putting hash d030b4d0f8f8e3ccd100251ffff9e0ff for cam 9613 in cache.
# Checking Duplicate: 9615
# Putting hash 200c64968100929100006cf88029c0ff for cam 9615 in cache.
# Checking Duplicate: 9614
# Putting hash c8d99c90800430d80400ffffe20c3dff for cam 9614 in cache.
# Checking Duplicate: 9272
# Checking Duplicate: 9616
# Checking Duplicate: 9714
# 202051_1-32_12_9272.jpg is a duplicate image.  Removing.
# Putting hash d0080181c898b2f3000000244d1800ff for cam 9714 in cache.
# Putting hash 485981c9a73262840000ffcf800060ff for cam 9616 in cache.
# Checking Duplicate: 9617
# Putting hash 1072d2ecce864b240133ffc18080c0ff for cam 9617 in cache.
# Checking Duplicate: 9302
# Checking Duplicate: 1185
# 202051_1-32_12_9302.jpg is a duplicate image.  Removing.
# Putting hash 48c436f8e8e295a6001ffcf0c8e800ff for cam 1185 in cache.
# Checking Duplicate: 9390
# 202051_1-32_12_9390.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9716
# 202051_1-32_12_9716.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9715
# 202051_1-32_12_9715.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1468
# Checking Duplicate: 1160
# Checking Duplicate: 1469
# 202051_1-32_12_1160.jpg is a duplicate image.  Removing.
# Putting hash f0f1f0f0f0e6eaca85080013f3e7e0ff for cam 1468 in cache.
# Putting hash 5bdcfcf8f0f282d0070078f9e0f020ff for cam 1469 in cache.
# Checking Duplicate: 1222
# 202051_1-32_12_1222.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1472
# Checking Duplicate: 9713
# Putting hash f8fcbcacbc7cd8f80010060a3c68d0ff for cam 1472 in cache.
# Putting hash 3c8958326b38349c60bf99e2ce6020ff for cam 9713 in cache.
# Checking Duplicate: 1314
# Putting hash 5e4eaeb4888440a0f3ff0000fbfcdfff for cam 1314 in cache.
# Checking Duplicate: 1470
# Putting hash be9e7eeca4e4b0a8000070f0b00000ff for cam 1470 in cache.
# Checking Duplicate: 1474
# Checking Duplicate: 1473
# 202051_1-32_12_1474.jpg is a duplicate image.  Removing.
# Putting hash 747458dcdcf3fe7b07200ff0f807ffff for cam 1473 in cache.
# Checking Duplicate: 1471
# Putting hash d8dcdcf8dcd8a0b000044cf0fcdb00ff for cam 1471 in cache.
# Checking Duplicate: 1475
# 202051_1-32_12_1475.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9743
# Putting hash e848b3f138341b1d0000fe87812402ff for cam 9743 in cache.
# Checking Duplicate: 9254
# 202051_1-32_13_9254.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9573
# cannot identify image file <_io.BytesIO object at 0x7ff2f5c64af0>
# Checking Duplicate: 1190
# Checking Duplicate: 9251
# Checking Duplicate: 9253
# Putting hash dffeacc8e4b2b8989f00005f890603ff for cam 9251 in cache.
# Putting hash d8cee7f3e8e43612e3f80cc73bc126ff for cam 1190 in cache.
# Putting hash 5b7ac081818faebc5f600000b3df0eff for cam 9253 in cache.
# Checking Duplicate: 9574
# Putting hash d8d89c9c9cf6f6b68443699919f980fe for cam 9574 in cache.
# Checking Duplicate: 9575
# Checking Duplicate: 9576
# 202051_1-32_13_9575.jpg is a duplicate image.  Removing.
# 202051_1-32_13_9576.jpg is a duplicate image.  Removing.
# Checking Duplicate: 5010
# 202051_1-32_13_5010.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9618
# 202051_1-32_13_9618.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9577
# Putting hash e2eefaec9c78fce8071df2c4193ff4ff for cam 9577 in cache.
# Checking Duplicate: 9579
# Checking Duplicate: 9493
# Putting hash bcb8d8b870f2909bfd2cd8fbfdc7a3ff for cam 9579 in cache.
# Putting hash dd1c4ccad8c882aa0037798830c100ff for cam 9493 in cache.
# Checking Duplicate: 9620
# Putting hash d0c88076328c96d200ffff0000e80cff for cam 9620 in cache.
# Checking Duplicate: 9619
# Putting hash 4e4decf6e280c0b000000fff400001ff for cam 9619 in cache.
# Checking Duplicate: 9491
# Putting hash 2cb0b1f8d8c9489208fcf7f1f48008ff for cam 9491 in cache.
# Checking Duplicate: 9492
# 202051_1-32_13_9492.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9494
# Checking Duplicate: 9495
# Checking Duplicate: 9496
# Putting hash e84c44961cf8b46400005c067df990ff for cam 9494 in cache.
# Checking Duplicate: 9501
# Checking Duplicate: 9730
# 202051_1-32_13_9496.jpg is a duplicate image.  Removing.
# Putting hash 2ba38c4d9b8bd7cb03e63dc0102800ff for cam 9495 in cache.
# 202051_1-32_13_9730.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9497
# Checking Duplicate: 9791
# Checking Duplicate: 9385
# Checking Duplicate: 9498
# Putting hash ec69c9e2e170869a0000ff1ee3e1c4ff for cam 9497 in cache.
# Putting hash 729afef48898fcee001ff8e00f0b00ff for cam 9501 in cache.
# Checking Duplicate: 9499
# Putting hash 5a4ba0d8c9d888040000af1088c3c3ff for cam 9385 in cache.
# 202051_1-32_13_9791.jpg is a duplicate image.  Removing.
# 202051_1-32_13_9499.jpg is a duplicate image.  Removing.
# Putting hash bcd8f1e0b23272360039ffcfb820007f for cam 9498 in cache.
# Checking Duplicate: 9386
# 202051_1-32_13_9386.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9731
# 202051_1-32_13_9731.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9500
# Putting hash cad28883d8cee366cc00300e33180bff for cam 9500 in cache.
# Checking Duplicate: 9210
# Putting hash dadc46dbc0f2e830fb00003f80f6c2ff for cam 9210 in cache.
# Checking Duplicate: 9300
# Putting hash c4bcf4499810f2e0ff3ff0c4083812ff for cam 9300 in cache.
# Checking Duplicate: 9096
# Putting hash d85e8fbdfce99913f300007ff0cc09ff for cam 9096 in cache.
# Checking Duplicate: 9301
# Putting hash 5e3c0662f090d2ca9c0014dee7f130ff for cam 9301 in cache.
# Checking Duplicate: 9687
# 202051_1-32_14_9687.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1161
# 202051_1-32_14_1161.jpg is a duplicate image.  Removing.
# Checking Duplicate: 4030
# 202051_1-32_14_4030.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9922
# Putting hash ba6b7978f8f0e0d0040fbd78f8f0e2ff for cam 9922 in cache.
# Checking Duplicate: 9621
# Putting hash caf0f8f362da68ec080001ffe70200ff for cam 9621 in cache.
# Checking Duplicate: 9921
# 202051_1-32_14_9921.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1476
# 202051_1-32_14_1476.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9622
# Checking Duplicate: 1477
# Checking Duplicate: 1478
# Putting hash a4e63691e1c931313fc87cfce60021ff for cam 1477 in cache.
# Putting hash 5e58c19d8cc20c8c1c0003fffd0207ff for cam 9622 in cache.
# Checking Duplicate: 1479
# Putting hash e6de4e1a76eccc54ffe20c3b77ee98ff for cam 1478 in cache.
# Putting hash e19ac4e0b0d4e2e3fff09f8f201100ff for cam 1479 in cache.
# Checking Duplicate: 1481
# Putting hash 9cc8cc9af8d4b4ec0000fffef30300ff for cam 1481 in cache.
# Checking Duplicate: 9255
# Putting hash d9d9eeccfce0a588010002fef8c200ff for cam 9255 in cache.
# Checking Duplicate: 9642
# Putting hash 3aa0e0e2e2cc949e0000ff3760c000ff for cam 9642 in cache.
# Checking Duplicate: 1297
# Putting hash db626068606064660008363fdf5b00f7 for cam 1297 in cache.
# Checking Duplicate: 9643
# Putting hash 0c0c004848240008000036c1006400ff for cam 9643 in cache.
# Checking Duplicate: 9639
# Checking Duplicate: 1187
# Checking Duplicate: 9623
# Putting hash 42c580f8e7305c6e02e07f11cc2711ff for cam 9639 in cache.
# Putting hash 524c38f0c090111100003ce0800203ff for cam 1187 in cache.
# 202051_1-32_14_9623.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1189
# Putting hash d8cee7f3e8e43612e3f80cc73bc126ff for cam 1189 in cache.
# Checking Duplicate: 9640
# Checking Duplicate: 9645
# Putting hash 8343168833e784269bc7fe1f70c601ff for cam 9640 in cache.
# Putting hash 302049cc8460191c0000e7d8bfc501ff for cam 9645 in cache.
# Checking Duplicate: 9086
# 202051_1-32_14_9086.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9641
# Checking Duplicate: 9646
# Putting hash 0e8cecfac6ccd8b4300cbfe206cc98ff for cam 9641 in cache.
# Checking Duplicate: 9644
# Putting hash 9018f0e8c89030a0be38f1e1891116ff for cam 9646 in cache.
# Putting hash da9a999b9eeeb6cc0000f9ff100c22ff for cam 9644 in cache.
# Checking Duplicate: 1303
# 202051_1-32_15_1303.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9088
# 202051_1-32_15_9088.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9087
# Putting hash 7a58f1dbcf73e8ec0000e110080603ff for cam 9087 in cache.
# Checking Duplicate: 9647
# Putting hash c7c7d6d0c6e164b88000e63b9c9f45ff for cam 9647 in cache.
# Checking Duplicate: 9089
# 202051_1-32_15_9089.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9090
# Putting hash 019c3cbc8cf8f1820fff00203c70e0ff for cam 9090 in cache.
# Checking Duplicate: 9080
# Putting hash daf0f160a0f8e0f1000018042fbb44ff for cam 9080 in cache.
# Checking Duplicate: 9648
# 202051_1-32_15_9648.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1484
# Putting hash 5a5c84a1b33050dedf0000ffcf3000ff for cam 1484 in cache.
# Checking Duplicate: 1191
# Putting hash dcde9698d8d0e4a4ffef9684b85000ff for cam 1191 in cache.
# Checking Duplicate: 1485
# 202051_1-32_15_1485.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1192
# Putting hash da5ab8849c74eab0005800041871c0ff for cam 1192 in cache.
# Checking Duplicate: 1489
# Putting hash d81496f8d0a4c989c0003f00d020c4ff for cam 1489 in cache.
# Checking Duplicate: 9651
# 202051_1-32_15_9651.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9650
# Putting hash a6aefedcbeee4e7cfffffc00008000ff for cam 9650 in cache.
# Checking Duplicate: 1487
# Putting hash da12e09830c4840c80fa001822c285ff for cam 1487 in cache.
# Checking Duplicate: 1486
# Checking Duplicate: 1193
# Checking Duplicate: 9649
# Checking Duplicate: 9652
# Putting hash 5e5c8cf9858dd8b4ef0008c0067c80ff for cam 1193 in cache.
# Putting hash 746848e4e2a1a46400e61865c4b303ff for cam 1486 in cache.
# Putting hash a5f0f0d0a848ecacffffc080010082ff for cam 9649 in cache.
# Putting hash f86efcf4dcb87ad2ff0f78e0000020ff for cam 9652 in cache.
# Checking Duplicate: 1491
# 202051_1-32_15_1491.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9655
# Putting hash a0a27cfcbcf4d4acfffffec0000101ff for cam 9655 in cache.
# Checking Duplicate: 9653
# Checking Duplicate: 9654
# Putting hash 42142666c4c2f2f6c2873f00800001ff for cam 9654 in cache.
# Checking Duplicate: 9659
# Putting hash a4f8f0f8d9882858ffffcfe0010e00ff for cam 9653 in cache.
# Putting hash d9d1828391d1e1e401d00000009202ff for cam 9659 in cache.
# Checking Duplicate: 9657
# Checking Duplicate: 9656
# 202051_1-32_16_9656.jpg is a duplicate image.  Removing.
# Putting hash 583071dfcfea6b6c80076fc0908000ff for cam 9657 in cache.
# Checking Duplicate: 9422
# Putting hash dc1c79e4eeebcdc400007fe16062c1ff for cam 9422 in cache.
# Checking Duplicate: 9658
# Checking Duplicate: 1194
# Checking Duplicate: 9660
# 202051_1-32_16_9658.jpg is a duplicate image.  Removing.
# Putting hash d858b9f0e2d3d3d90000ff7180007eff for cam 1194 in cache.
# Putting hash a3e6fefff6fefcfcfffff000000000ff for cam 9660 in cache.
# Checking Duplicate: 9661
# Putting hash a0a2ca987afab0b4ec3fff1f608000ff for cam 9661 in cache.
# Checking Duplicate: 9662
# Checking Duplicate: 9663
# Putting hash 5adab8f2b03c79f848001be6800040ff for cam 9662 in cache.
# 202051_1-32_16_9663.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9666
# 202051_1-32_16_9666.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9664
# Checking Duplicate: 1195
# 202051_1-32_16_1195.jpg is a duplicate image.  Removing.
# Putting hash 9aceece098b42848003ff8c00000a4ff for cam 9664 in cache.
# Checking Duplicate: 9665
# Putting hash 5adef6fef0e48c380000fffcc0c20cff for cam 9665 in cache.
# Checking Duplicate: 1492
# 202051_1-32_16_1492.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9668
# Putting hash 5b58a064f5b03030ff500078cfb783ff for cam 9668 in cache.
# Checking Duplicate: 9667
# Putting hash 5a58e8c5cc86f6d0d700000fff0f3eff for cam 9667 in cache.
# Checking Duplicate: 1493
# Checking Duplicate: 1197
# 202051_1-32_16_1493.jpg is a duplicate image.  Removing.
# Putting hash 585848b9b1385e1c00000c0181276fff for cam 1197 in cache.
# Checking Duplicate: 1198
# Checking Duplicate: 9669
# Putting hash 5a5af8fdf3f2f4e4ff0000f9f31b42ff for cam 1198 in cache.
# Putting hash f8e4c4a498f868b800000207bd9200ff for cam 9669 in cache.
# Checking Duplicate: 1494
# Putting hash ef4ebce024b03834f7060000cf07a3ff for cam 1494 in cache.
# Checking Duplicate: 1199
# 202051_1-32_16_1199.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9672
# 202051_1-32_17_9672.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9670
# Putting hash 5c9d929b8dc628f20000e073bfdf00ff for cam 9670 in cache.
# Checking Duplicate: 1201
# Checking Duplicate: 9671
# Checking Duplicate: 1200
# Putting hash 1ebf1cf9eddcb46c00007ff16bdf30ff for cam 1201 in cache.
# 202051_1-32_16_1200.jpg is a duplicate image.  Removing.
# Putting hash 3d3e165cfcf4e4dc0100047ffbb2c4ff for cam 9671 in cache.
# Checking Duplicate: 1203
# Putting hash 4a58616460c226f00000ffff608000ff for cam 1203 in cache.
# Checking Duplicate: 1499
# Checking Duplicate: 9677
# 202051_1-32_17_9677.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9674
# Checking Duplicate: 9673
# Checking Duplicate: 1202
# Checking Duplicate: 1497
# Putting hash 7a3c3c3ce4bcd89400007ffbfffc00ff for cam 1499 in cache.
# Checking Duplicate: 9077
# 202051_1-32_17_9673.jpg is a duplicate image.  Removing.
# 202051_1-32_17_9674.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1498
# 202051_1-32_17_9077.jpg is a duplicate image.  Removing.
# Putting hash d470d0c9c2e0e0d0000064b91e0761ff for cam 1497 in cache.
# Checking Duplicate: 9675
# Putting hash cc8c8cc0e6cbecb60080f89f04f2c9ff for cam 1202 in cache.
# Putting hash fdbff8e28c8c5cf8e03cf1c6060f08ff for cam 1498 in cache.
# Checking Duplicate: 9676
# Putting hash 5a5a91c2585e6f3e0000ff8681974fff for cam 9675 in cache.
# Putting hash 59cdc5e4c4448e320000ffec814100ff for cam 9676 in cache.
# Checking Duplicate: 1204
# 202051_1-32_17_1204.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9291
# 202051_1-32_17_9291.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9079
# 202051_1-32_17_9079.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1502
# Checking Duplicate: 1304
# Putting hash d8d8e0b8f818f9f80cf00000021828ff for cam 1502 in cache.
# Putting hash b87062e4b0f03060f8f00204fcc120ff for cam 1304 in cache.
# Checking Duplicate: 9745
# Putting hash dbf8b898d878e8d80e00e03f1f79e0ff for cam 9745 in cache.
# Checking Duplicate: 1503
# Putting hash f8fcd862fcb0beda0f200047ffe700ff for cam 1503 in cache.
# Checking Duplicate: 9744
# Putting hash fcb430f0f0e8ecf400187fa7060b09ff for cam 9744 in cache.
# Checking Duplicate: 9746
# Putting hash f8ecccc0e0e8f6ba8020789e874904ff for cam 9746 in cache.
# Checking Duplicate: 9678
# Putting hash 2c8edae0e4e6e3f500003c82b9344aff for cam 9678 in cache.
# Checking Duplicate: 9747
# 202051_1-32_17_9747.jpg is a duplicate image.  Removing.
# Checking Duplicate: 9749
# 202051_1-32_17_9749.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1504
# cannot identify image file <_io.BytesIO object at 0x7ff2f5c621a8>
# Checking Duplicate: 9748
# Putting hash dd99b9e1d090b0b0001c73e1881010ff for cam 9748 in cache.
# Checking Duplicate: 1505
# Putting hash edd91247c7eef880e000107f9ffef0ff for cam 1505 in cache.
# Checking Duplicate: 1506
# Putting hash 59c9c8e0e1e0e4e0200088fcc72301ff for cam 1506 in cache.
# Checking Duplicate: 1507
# Putting hash eefdd9ac30928d9cca00d10061b206ff for cam 1507 in cache.
# Checking Duplicate: 1332
# Checking Duplicate: 1508
# Checking Duplicate: 1173
# Putting hash 5e5c96e674eca2a2d74000ce41fdc0ff for cam 1332 in cache.
# 202051_1-32_18_1173.jpg is a duplicate image.  Removing.
# Putting hash cb6e72fcf078e393000040ffa770e2ff for cam 1508 in cache.
# Checking Duplicate: 9725
# 202051_1-32_18_9725.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1208
# 202051_1-32_18_1208.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1509
# 202051_1-32_18_1509.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1331
# 202051_1-32_18_1331.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1510
# Putting hash 60e4e9e8fcf0e8d842003f6afcf4c0ff for cam 1510 in cache.
# Checking Duplicate: 1512
# Checking Duplicate: 1207
# Checking Duplicate: 9091
# 202051_1-32_18_9091.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1511
# Putting hash be96f6ecdc70e0a0e03efeec187080ff for cam 1512 in cache.
# Checking Duplicate: 1306
# Putting hash d2da327afcb6eee600c8377fd0837eff for cam 1207 in cache.
# 202051_1-32_18_1306.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1308
# Putting hash d2c6c6e2c8fceaebff303c468f1500ff for cam 1511 in cache.
# Putting hash 8ca9898d1cb8f082007cff881c7b81ff for cam 1308 in cache.
# Checking Duplicate: 1514
# 202051_1-32_18_1514.jpg is a duplicate image.  Removing.
# Checking Duplicate: 1515
# Putting hash 209391b2cac6b8e06804ffffc14e30ff for cam 1515 in cache.
# Checking Duplicate: 9679
# Putting hash 4c48cd3aa68c98da00088962e6c801ff for cam 9679 in cache.
# Checking Duplicate: 1516
# Putting hash d9c1f3e8eea2d1a5000117e3c90012ff for cam 1516 in cache.
# Checking Duplicate: 9680
# Putting hash 89f8f9adf7d87cfe01ff738b448338ff for cam 9680 in cache.
# Checking Duplicate: 9681
# ...
# Putting hash 8de4b3bdbeb89e9c110c070f046024ff for cam bellevue-034w in cache.
# Checking Duplicate: bellevue-034s
# 202051_1-33_28_bellevue-034s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-034e
# Putting hash 89b951c9e8b8da6c1efa47814f2482ff for cam bellevue-034e in cache.
# Checking Duplicate: bellevue-035n
# Checking Duplicate: bellevue-035w
# Putting hash 33ca71383eb29092309ec703787e28ff for cam bellevue-035n in cache.
# Checking Duplicate: bellevue-035s
# 202051_1-33_28_bellevue-035w.jpg is a duplicate image.  Removing.
# Putting hash 1af2f190b82cec9c3ef6e79f03e700ff for cam bellevue-035s in cache.
# Checking Duplicate: bellevue-035e
# Checking Duplicate: bellevue-036n
# Putting hash 617168e4cceadce44eff7be0094f30ff for cam bellevue-035e in cache.
# Putting hash 3fb3f0ecc8cedf74003ef7f5010818ff for cam bellevue-036n in cache.
# Checking Duplicate: bellevue-036w
# Checking Duplicate: bellevue-036s
# Checking Duplicate: bellevue-042n
# Putting hash 4fe5b2b03818cc9958ccc6f3032648ff for cam bellevue-036w in cache.
# Checking Duplicate: bellevue-038n
# image file is truncated (17 bytes not processed)
# Checking Duplicate: bellevue-036e
# 202051_1-33_28_bellevue-038n.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-038w
# Putting hash 571b38d2f8fcbc6c003ef896431f07ff for cam bellevue-036e in cache.
# Putting hash 161c1bb3c2a2c2c2045d3831c97178df for cam bellevue-036s in cache.
# Checking Duplicate: bellevue-038e
# Checking Duplicate: bellevue-038s
# Putting hash 6f62e2f4b2b120a428eecf8c809810ef for cam bellevue-038w in cache.
# Checking Duplicate: bellevue-039n
# 202051_1-33_28_bellevue-038e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-039w
# Checking Duplicate: bellevue-039s
# Checking Duplicate: bellevue-039e
# 202051_1-33_28_bellevue-039w.jpg is a duplicate image.  Removing.
# Putting hash 63687cbac9c66e26ae07e1f0111fc0ff for cam bellevue-039n in cache.
# Putting hash 7b313bbb83a7b2a21fcf7ff8820d60ff for cam bellevue-038s in cache.
# Putting hash 3fd5c44095e9e1e37edfc0c234780cef for cam bellevue-039s in cache.
# Checking Duplicate: bellevue-040w
# Checking Duplicate: bellevue-040n
# Checking Duplicate: bellevue-040s
# Checking Duplicate: bellevue-042s
# image file is truncated (16 bytes not processed)
# Putting hash 39d8e8c8d898bc8c7ff30c0403db07ff for cam bellevue-039e in cache.
# Putting hash 9d9838a3138181d1001df9e0446528ff for cam bellevue-040w in cache.
# Putting hash 1360e9e6acbc64f01ee61bc60c3808ff for cam bellevue-040n in cache.
# Putting hash bff0c098889990d03cfcc705081800ff for cam bellevue-040s in cache.
# Checking Duplicate: bellevue-040e
# Putting hash cdc1d8928881c6c41cffc10000b100ff for cam bellevue-040e in cache.
# Checking Duplicate: bellevue-041n
# Putting hash 19986a588c8890d43ffd8643001c00ff for cam bellevue-041n in cache.
# Checking Duplicate: bellevue-041s
# Checking Duplicate: bellevue-041w
# Checking Duplicate: bellevue-041e
# Putting hash 1670f0d2f8f071541e63c180008000ff for cam bellevue-041w in cache.
# Putting hash ffe6e9eeeeef92d6b07f7f30e0cc20ff for cam bellevue-041s in cache.
# Putting hash b030d4a4a0606367f7635199913901ff for cam bellevue-041e in cache.
# Checking Duplicate: bellevue-042w
# 202051_1-33_29_bellevue-042w.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-042e
# 202051_1-33_29_bellevue-042e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-043n
# Putting hash 117070e2a0a1a7661018e17eb7cf80ff for cam bellevue-043n in cache.
# Checking Duplicate: bellevue-043w
# Putting hash 7c78f0f0f8bd94a0fcf9e307c36900ff for cam bellevue-043w in cache.
# Checking Duplicate: bellevue-043s
# 202051_1-33_29_bellevue-043s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-045n
# Checking Duplicate: bellevue-043e
# 202051_1-33_29_bellevue-043e.jpg is a duplicate image.  Removing.
# Putting hash 1d32f3919494b3721c7cfe9307b901ff for cam bellevue-045n in cache.
# Checking Duplicate: bellevue-045w
# Putting hash f3f1f279dc9c9e59fee7862b034124ff for cam bellevue-045w in cache.
# Checking Duplicate: bellevue-045s
# Putting hash c540969698939297ff4bc0b4090900ff for cam bellevue-045s in cache.
# Checking Duplicate: bellevue-045e
# Checking Duplicate: bellevue-047n
# Putting hash 38e060b8999190943b034c60a1f310ff for cam bellevue-045e in cache.
# Checking Duplicate: bellevue-047s
# Checking Duplicate: bellevue-047w
# Putting hash 2594e8c9c546dac400fda4e3016e10ff for cam bellevue-047n in cache.
# Checking Duplicate: bellevue-047e
# Putting hash 4c58dab1b4f8a44c0c1cc03320d307ff for cam bellevue-047e in cache.
# Putting hash 43cca82a92e6e6e1028100e8327b0cff for cam bellevue-047s in cache.
# Checking Duplicate: bellevue-052n
# Putting hash 1301b01014989898000f8322145c00ff for cam bellevue-047w in cache.
# Checking Duplicate: bellevue-048w
# image file is truncated (54 bytes not processed)
# Checking Duplicate: bellevue-048n
# Putting hash 5be5e6d4da48eee6503de7d5800101ff for cam bellevue-048w in cache.
# Putting hash 074cf9edccd93c2c3e1ee2650c8302ff for cam bellevue-048n in cache.
# Checking Duplicate: bellevue-048e
# Checking Duplicate: bellevue-048s
# Checking Duplicate: bellevue-049n
# Checking Duplicate: bellevue-049w
# Putting hash 1bcf2aba9cece0e23fdfe860307d1cff for cam bellevue-048e in cache.
# Checking Duplicate: bellevue-049s
# Putting hash 1b4d464a546caaa20039ffff10fc08ff for cam bellevue-048s in cache.
# Checking Duplicate: bellevue-049e
# Putting hash 2d3cc049a088a616fcff00d8c7b880ff for cam bellevue-049n in cache.
# Checking Duplicate: bellevue-050n
# Checking Duplicate: bellevue-050w
# Putting hash 697af2b2d4f0f6e67d794b7f1e0030ff for cam bellevue-049w in cache.
# Putting hash 19940c0adac26bcb7f97012d1bb060ff for cam bellevue-049s in cache.
# Putting hash 33f4b4ecedcdb5301ffb042442dd1fff for cam bellevue-049e in cache.
# Putting hash 7160f8e1d1e0dbd436ffc00c130f0bff for cam bellevue-050w in cache.
# Putting hash 3b709c343471b5e738ffdabd3dd038ff for cam bellevue-050n in cache.
# Checking Duplicate: bellevue-052e
# image file is truncated (25 bytes not processed)
# Checking Duplicate: bellevue-051w
# Checking Duplicate: bellevue-051n
# image file is truncated (19 bytes not processed)
# 202051_1-33_29_bellevue-051w.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-051s
# 202051_1-33_29_bellevue-051s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-052w
# image file is truncated (49 bytes not processed)
# Checking Duplicate: bellevue-051e
# 202051_1-33_29_bellevue-051e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-050s
# 202051_1-33_29_bellevue-050s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-052s
# image file is truncated (51 bytes not processed)
# Checking Duplicate: bellevue-050e
# Putting hash 3998dcd89848603062bfe100b2180cff for cam bellevue-050e in cache.
# Checking Duplicate: bellevue-053n
# Checking Duplicate: bellevue-053s
# Checking Duplicate: bellevue-053w
# Putting hash 61e190332979c1d17fff84007e6000ff for cam bellevue-053s in cache.
# Putting hash 90f0f8ecf2f2f4f53f77fbfda202c0ff for cam bellevue-053n in cache.
# Putting hash 70f2c0301ccccc8cfcf6c7c3233358ff for cam bellevue-053w in cache.
# Checking Duplicate: bellevue-055n
# Checking Duplicate: bellevue-053e
# Putting hash 9b9b7cfaf6ee218068bffff8f6fe60ff for cam bellevue-055n in cache.
# Putting hash e8e4b8b2b2b8b4941fdfc068b68a00ff for cam bellevue-053e in cache.
# Checking Duplicate: bellevue-055w
# Putting hash 3878f09494a4c4d41ef8c183332f0eff for cam bellevue-055w in cache.
# Checking Duplicate: bellevue-055s
# 202051_1-33_30_bellevue-055s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-055e
# 202051_1-33_30_bellevue-055e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-057n
# 202051_1-33_30_bellevue-057n.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-057w
# Checking Duplicate: bellevue-057s
# Checking Duplicate: bellevue-057e
# Putting hash 5d9ce0c4cc9961625fbd22c6041818ff for cam bellevue-057s in cache.
# Putting hash 4cd8725cf5b438381f9906180780f0ff for cam bellevue-057w in cache.
# Checking Duplicate: bellevue-058n
# Putting hash 64eac2bcbcce89cc7ff80683004483ff for cam bellevue-057e in cache.
# Putting hash d09edcf8f0f0e0a49f1f9cd8f07080ff for cam bellevue-058n in cache.
# Checking Duplicate: bellevue-058w
# 202051_1-33_30_bellevue-058w.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-058s
# Putting hash ffbf7ebe3d3db89a809ffdf8b0d4a0ff for cam bellevue-058s in cache.
# Checking Duplicate: bellevue-058e
# 202051_1-33_30_bellevue-058e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-060n
# Checking Duplicate: bellevue-060w
# Putting hash 63f0baa5ced2d2c47ff3c0212ce200ff for cam bellevue-060n in cache.
# Putting hash 646666a231d1a090006fe4ce22d328ff for cam bellevue-060w in cache.
# Checking Duplicate: bellevue-060s
# Putting hash 430c30e4cececeecc20c338003d704ff for cam bellevue-060s in cache.
# Checking Duplicate: bellevue-060e
# 202051_1-33_30_bellevue-060e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-061n
# Checking Duplicate: bellevue-061w
# Putting hash 9af1b4f2f2b333231ed32c49c08861ff for cam bellevue-061n in cache.
# Checking Duplicate: bellevue-061s
# Checking Duplicate: bellevue-061e
# Putting hash 37c994ba6b113bf37ceb0180000078ff for cam bellevue-061s in cache.
# Putting hash 7890f3edcc949d4e49f10283000030ff for cam bellevue-061w in cache.
# Checking Duplicate: bellevue-059n
# Putting hash 79f4ae22949692cb7fddc062e03c14ff for cam bellevue-061e in cache.
# Checking Duplicate: bellevue-062n
# Checking Duplicate: bellevue-059w
# Checking Duplicate: bellevue-059e
# Putting hash 0c6060663238d85a3c9f934f0e36b8ff for cam bellevue-062n in cache.
# Checking Duplicate: bellevue-062w
# Putting hash 7decc34377969c3c7c31c18b62568c78 for cam bellevue-059n in cache.
# Putting hash 0264e0f1f1e1d2e3127ceec78101134f for cam bellevue-059w in cache.
# Putting hash 0e263cbcf46569e2004e3c38f03459cf for cam bellevue-062w in cache.
# Putting hash 53d4b03472b5b4f54f8091b54e333080 for cam bellevue-059e in cache.
# Checking Duplicate: bellevue-059s
# Putting hash 679160c89666aeb44cbf6fc10070de06 for cam bellevue-059s in cache.
# Checking Duplicate: bellevue-062e
# Checking Duplicate: bellevue-063n
# Checking Duplicate: bellevue-062s
# Putting hash 6372c4c4c6e49484ff7fc107daeef03f for cam bellevue-062e in cache.
# Checking Duplicate: bellevue-063w
# Putting hash 0b59c1060c981c7c1cffc30e000f07ff for cam bellevue-063n in cache.
# Putting hash 77a7b2b030309ce4fcffceb20f6733ff for cam bellevue-062s in cache.
# Checking Duplicate: bellevue-063s
# Putting hash 494140c08196969c383f41c0830300ff for cam bellevue-063w in cache.
# Putting hash 7dede5dc4ce8b2b470f9af345c4800ff for cam bellevue-063s in cache.
# Checking Duplicate: bellevue-063e
# Putting hash 63c6eeecf4ede0e000fff88276b81cff for cam bellevue-063e in cache.
# Checking Duplicate: bellevue-064w
# Checking Duplicate: bellevue-064n
# Checking Duplicate: bellevue-069n
# image file is truncated (44 bytes not processed)
# 202051_1-33_31_bellevue-064n.jpg is a duplicate image.  Removing.
# Putting hash 0030f1786c78342c043c870300c307ff for cam bellevue-064w in cache.
# Checking Duplicate: bellevue-064s
# Checking Duplicate: bellevue-069w
# image file is truncated (35 bytes not processed)
# Putting hash 1ea2049ecfddce9910a7010020f000ff for cam bellevue-064s in cache.
# Checking Duplicate: bellevue-064e
# Checking Duplicate: bellevue-065n
# 202051_1-33_31_bellevue-064e.jpg is a duplicate image.  Removing.
# Putting hash 30f0c492b0b910d03effc17e9e0808ff for cam bellevue-065n in cache.
# Checking Duplicate: bellevue-065w
# 202051_1-33_31_bellevue-065w.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-065s
# Checking Duplicate: bellevue-065e
# Putting hash 1c7060e0a4e448401c7fe2db8134c0ff for cam bellevue-065s in cache.
# Checking Duplicate: bellevue-069e
# image file is truncated (4 bytes not processed)
# Checking Duplicate: bellevue-066n
# Putting hash 1a1a92e226c6c6c404f8bb8771ce26ff for cam bellevue-065e in cache.
# Putting hash 183874c6a642abc31fa371ffad5520bf for cam bellevue-066n in cache.
# Checking Duplicate: bellevue-066w
# Putting hash 39cc4a3292c2e6a473fcc1633b0206ff for cam bellevue-066w in cache.
# Checking Duplicate: bellevue-066s
# 202051_1-33_31_bellevue-066s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-066e
# Checking Duplicate: bellevue-068n
# Putting hash f3f1e0dad498ce4cb4e321dac0310eff for cam bellevue-066e in cache.
# 202051_1-33_31_bellevue-068n.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-068w
# Putting hash 4ac839d1b1c1c1e1408878d0207018ef for cam bellevue-068w in cache.
# Checking Duplicate: bellevue-068s
# Putting hash 49e8e1c0c474a49c0ff86119864707ff for cam bellevue-068s in cache.
# Checking Duplicate: bellevue-068e
# Putting hash 296470d0d8cce8ea1b2d6180120401ff for cam bellevue-068e in cache.
# Checking Duplicate: bellevue-069s
# 202051_1-33_31_bellevue-069s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-070n
# Checking Duplicate: bellevue-070s
# Checking Duplicate: bellevue-070w
# Putting hash 9e9c28980ca888c0dcf803305c6538ff for cam bellevue-070n in cache.
# Putting hash 4f62e8f3a7a6c6a6087fe9c1302802ff for cam bellevue-070w in cache.
# Putting hash b68232b6b71a903c043fdfe0044e80ff for cam bellevue-070s in cache.
# Checking Duplicate: bellevue-070e
# Putting hash 2d71326b646ae48608453fa3d47340ff for cam bellevue-070e in cache.
# Checking Duplicate: bellevue-071n
# Putting hash 1c7cd8b8e1e1f3db3f7d48b00001e0ff for cam bellevue-071n in cache.
# Checking Duplicate: bellevue-071e
# Checking Duplicate: bellevue-071w
# Checking Duplicate: bellevue-071s
# Checking Duplicate: bellevue-072n
# Putting hash 2160c88c8c0c0c043fe3c0dc808100ff for cam bellevue-071s in cache.
# Putting hash fbb17c6369c04020dcbf9c6063c1c0ff for cam bellevue-071e in cache.
# 202051_1-33_32_bellevue-072n.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-072w
# Putting hash 7de4a424a4cafaf2fae380342d0c00ff for cam bellevue-071w in cache.
# Checking Duplicate: bellevue-072s
# Checking Duplicate: bellevue-072e
# 202051_1-33_32_bellevue-072s.jpg is a duplicate image.  Removing.
# 202051_1-33_32_bellevue-072e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-073n
# Putting hash 9c9cd4c1c2c674703ffef0991b0e1cff for cam bellevue-072w in cache.
# Checking Duplicate: bellevue-073w
# Checking Duplicate: bellevue-073s
# 202051_1-33_32_bellevue-073n.jpg is a duplicate image.  Removing.
# 202051_1-33_32_bellevue-073w.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-073e
# Putting hash 5b3b7959383aba8a18b2efdb1d6360ff for cam bellevue-073s in cache.
# Checking Duplicate: bellevue-074n
# 202051_1-33_32_bellevue-073e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-074w
# Putting hash 99198c31896c5a9b000018f7bf4d40ff for cam bellevue-074n in cache.
# Putting hash bfbbf0f0f0e6e8f00038fec7806e08ff for cam bellevue-074w in cache.
# Checking Duplicate: bellevue-074s
# Checking Duplicate: bellevue-075n
# Putting hash fb0b31a0a4c5cce6c0007fe3217700ff for cam bellevue-074s in cache.
# Checking Duplicate: bellevue-074e
# 202051_1-33_32_bellevue-075n.jpg is a duplicate image.  Removing.
# Putting hash 686969c9f5b59ddc0000ff19c06621df for cam bellevue-074e in cache.
# Checking Duplicate: bellevue-075w
# Checking Duplicate: bellevue-075s
# Putting hash ec8cd8f0f0a6aceceebed921f3d738ff for cam bellevue-075w in cache.
# 202051_1-33_32_bellevue-075s.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-075e
# Putting hash b7f4b8a4cac8c8cd2ceeb320c200e0ff for cam bellevue-075e in cache.
# Checking Duplicate: bellevue-076n
# Checking Duplicate: bellevue-076w
# Putting hash 36f248b4125a3ad87ff6cb21844400ff for cam bellevue-076n in cache.
# Checking Duplicate: bellevue-076s
# 202051_1-33_32_bellevue-076w.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-076e
# Putting hash f9b268cc92128a23ddffe3c88030c8ff for cam bellevue-076s in cache.
# 202051_1-33_32_bellevue-076e.jpg is a duplicate image.  Removing.
# Checking Duplicate: bellevue-078n
# Putting hash f0f0deb8b99aa283ffe3dc006130c0ff for cam bellevue-078n in cache.
# Checking Duplicate: bellevue-078w
# Putting hash 01e0e8262030b0b41ff7998c4c0910ff for cam bellevue-078w in cache.
