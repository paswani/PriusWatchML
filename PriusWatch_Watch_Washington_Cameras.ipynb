# %% [markdown]
# Clone PriusWatchML Repo

# %%
# !git clone -l -s https://cchighman:Laracos12@github.com/cchighman/PriusWatchML.git cloned-repo
# %cd cloned-repo
# Out:
# Cloning into 'cloned-repo'...
# ...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 83 (delta 7), reused 0 (delta 0), pack-reused 68
# Unpacking objects: 100% (83/83), done.
# /content/cloned-repo

# %% [markdown]
# Install Modules

# %%
# !pip install dhash
# !pip install timeloop
# Out:
# ...
#   Created wheel for dhash: filename=dhash-1.3-cp36-none-any.whl size=7274 sha256=4e0a290c819dba3ab921457b77e5479a59e3657f68726ad3a6e6160a51b1ffd7
#   Stored in directory: /root/.cache/pip/wheels/a4/cb/88/d7cf61a1ac52042d59cc0c7a130c04b1541dfd439570c6ea41
# Successfully built dhash
# ...
#   Created wheel for timeloop: filename=timeloop-1.0.2-cp36-none-any.whl size=3721 sha256=ce251576570d69e3e729609ac7a680154fc0fc0e065453f95016b4bd1e57e2de
#   Stored in directory: /root/.cache/pip/wheels/70/e7/0e/d125f034638a6f46b47b419e51b9c5885f23c054072579d791
# Successfully built timeloop
# ...

# %% [markdown]
# Save Images to Drive

# %%
# !python watch_cameras.py --path "../drive/My Drive/frames/" --cams min_cams2.json --timer 60
# Out:
# Cameras job current time : Sat Apr 25 09:47:53 2020
# Checking Duplicate: CMR-0093
# 2020425_9-47_53_CMR-0093.jpg is a duplicate image.  Removing.
# Checking Duplicate: CMR-0247
# Checking Duplicate: CMR-0144
# 2020425_9-47_53_CMR-0247.jpg is a duplicate image.  Removing.
# Checking Duplicate: CMR-0013
# Checking Duplicate: CMR-0230
# 2020425_9-47_53_CMR-0144.jpg is a duplicate image.  Removing.
# Checking Duplicate: CMR-0094
# Checking Duplicate: CMR-0250
# Checking Duplicate: CMR-0010
# Checking Duplicate: CMR-0006
# Checking Duplicate: CMR-0113
# Checking Duplicate: CMR-0252
# Checking Duplicate: CMR-0108
# Checking Duplicate: CMR-0245
# Checking Duplicate: CMR-0011
# Checking Duplicate: CMR-0032
# Checking Duplicate: CMR-0143
# Checking Duplicate: CMR-0246
# Checking Duplicate: CMR-0135
# Checking Duplicate: CMR-0145
# Checking Duplicate: CMR-0009
# Checking Duplicate: CMR-0012
# Checking Duplicate: CMR-0112
# Checking Duplicate: CMR-0007
# Checking Duplicate: CMR-0038
# ...
