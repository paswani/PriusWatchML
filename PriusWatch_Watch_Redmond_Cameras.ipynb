# %% [markdown]
# Clone PriusWatchML Repo

# %%
# !git clone -l -s https://cchighman:8059ebaec5cf2f09c29b55d649f7e688d3b24bd8@github.com/cchighman/PriusWatchML.git cloned-repo
# %cd cloned-repo
# Out:
# Cloning into 'cloned-repo'...
# ...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 224 (delta 8), reused 0 (delta 0), pack-reused 208
# Receiving objects: 100% (224/224), 1012.69 KiB | 2.66 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# /content/cloned-repo

# %% [markdown]
# Execute Python Script

# %%
# !pip install dhash
# !pip install timeloop
# Out:
# ...
#   Created wheel for dhash: filename=dhash-1.3-cp36-none-any.whl size=7274 sha256=7b4928b7b0a4a5a94fb73d943da4b138e59b9ee980c9bf90c33f80d2cdf3776a
#   Stored in directory: /root/.cache/pip/wheels/a4/cb/88/d7cf61a1ac52042d59cc0c7a130c04b1541dfd439570c6ea41
# Successfully built dhash
# ...
#   Created wheel for timeloop: filename=timeloop-1.0.2-cp36-none-any.whl size=3721 sha256=d3233a5a5a7d6fc405c4fc0767c96d2c08ecc0b77ae2c7fc50657b4defd11f3a
#   Stored in directory: /root/.cache/pip/wheels/70/e7/0e/d125f034638a6f46b47b419e51b9c5885f23c054072579d791
# Successfully built timeloop
# ...

# %%
# !python watch_cameras.py --path "../drive/My Drive/frames/" --cams redmond_cams.json --timer 20
# Out:
# Streaming output truncated to the last 5000 lines.
# Checking Duplicate: redmond-84
# Checking Duplicate: redmond-76
# Checking Duplicate: redmond-39
# 2020430_17-33_11_redmond-76.jpg is a duplicate image.  Removing.
# 2020430_17-33_9_redmond-28.jpg is a duplicate image.  Removing.
# 2020430_17-33_11_redmond-84.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-88
# 2020430_17-33_9_redmond-39.jpg is a duplicate image.  Removing.
# 2020430_17-33_12_redmond-88.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-94
# 2020430_17-33_12_redmond-94.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-81
# 2020430_17-33_11_redmond-81.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-96
# 2020430_17-33_12_redmond-96.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-89
# 2020430_17-33_12_redmond-89.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-37
# Checking Duplicate: redmond-92
# ...
