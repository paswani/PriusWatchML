# %% [markdown]
# Clone PriusWatchML Repo

# %%
# !git clone -l -s https://cchighman:Laracos12@github.com/cchighman/PriusWatchML.git cloned-repo
# %cd cloned-repo
# Out:
# Cloning into 'cloned-repo'...
# warning: --local is ignored
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 83 (delta 7), reused 0 (delta 0), pack-reused 68
# Unpacking objects: 100% (83/83), done.
# /content/cloned-repo

# %% [markdown]
# Execute Python Script

# %%
# !pip install dhash
# !pip install timeloop
# Out:
# Collecting dhash
#   Downloading https://files.pythonhosted.org/packages/3d/98/621b5dffc1d47135377ceeebd173f0daaa3e4c993a4dfd5cc0d63a3ffdbd/dhash-1.3.tar.gz
# Building wheels for collected packages: dhash
#   Building wheel for dhash (setup.py) ... done
#   Created wheel for dhash: filename=dhash-1.3-cp36-none-any.whl size=7274 sha256=ca6c1e5d072734785e5a08f7da8d801ab3ea74a263312bc0fdc12e4706ed4fc1
#   Stored in directory: /root/.cache/pip/wheels/a4/cb/88/d7cf61a1ac52042d59cc0c7a130c04b1541dfd439570c6ea41
# Successfully built dhash
# Installing collected packages: dhash
# Successfully installed dhash-1.3
# Collecting timeloop
#   Downloading https://files.pythonhosted.org/packages/6a/95/3e39ee32f15a8e9dea46bb52300611a5351964eeaa393bafb0d738e90ce0/timeloop-1.0.2.tar.gz
# Building wheels for collected packages: timeloop
#   Building wheel for timeloop (setup.py) ... done
#   Created wheel for timeloop: filename=timeloop-1.0.2-cp36-none-any.whl size=3721 sha256=17a445e5373766f76aa803221dcdb64f880db43fe20055c2d8bf50821c976bd4
#   Stored in directory: /root/.cache/pip/wheels/70/e7/0e/d125f034638a6f46b47b419e51b9c5885f23c054072579d791
# Successfully built timeloop
# Installing collected packages: timeloop
# Successfully installed timeloop-1.0.2

# %%
# !python watch_cameras.py --path "../drive/My Drive/frames/" --cams redmond_cams.json --timer 20
# Out:
# Cameras job current time : Sat Apr 25 09:47:19 2020
# Checking Duplicate: redmond-16
# 2020425_9-47_19_redmond-16.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-1
# 2020425_9-47_19_redmond-1.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-3
# 2020425_9-47_19_redmond-3.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-12
# 2020425_9-47_19_redmond-12.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-25
# 2020425_9-47_19_redmond-25.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-20
# Checking Duplicate: redmond-24
# Checking Duplicate: redmond-30
# Checking Duplicate: redmond-8
# Checking Duplicate: redmond-26
# Checking Duplicate: redmond-22
# Checking Duplicate: redmond-5
# Checking Duplicate: redmond-28
# 2020425_9-47_19_redmond-8.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-14
# Checking Duplicate: redmond-10
# 2020425_9-47_19_redmond-24.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-15
# 2020425_9-47_19_redmond-30.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-7
# 2020425_9-47_19_redmond-20.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-21
# 2020425_9-47_19_redmond-22.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-26.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-15.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-14.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-10.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-28.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-7.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-5.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-21.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-2
# 2020425_9-47_19_redmond-2.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-11
# Checking Duplicate: redmond-13
# Checking Duplicate: redmond-4
# 2020425_9-47_19_redmond-11.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-13.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-4.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-9
# 2020425_9-47_19_redmond-9.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-6
# 2020425_9-47_19_redmond-6.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-18
# Checking Duplicate: redmond-23
# 2020425_9-47_19_redmond-18.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-23.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-32
# 2020425_9-47_20_redmond-32.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-31
# 2020425_9-47_20_redmond-31.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-19
# 2020425_9-47_19_redmond-19.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-17
# Checking Duplicate: redmond-33
# 2020425_9-47_20_redmond-33.jpg is a duplicate image.  Removing.
# 2020425_9-47_19_redmond-17.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-46
# 2020425_9-47_20_redmond-46.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-55
# 2020425_9-47_20_redmond-55.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-39
# 2020425_9-47_20_redmond-39.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-58
# Checking Duplicate: redmond-54
# 2020425_9-47_20_redmond-58.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-54.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-40
# Checking Duplicate: redmond-42
# 2020425_9-47_20_redmond-40.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-42.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-43
# 2020425_9-47_20_redmond-43.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-51
# Checking Duplicate: redmond-49
# 2020425_9-47_20_redmond-51.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-50
# Checking Duplicate: redmond-47
# Checking Duplicate: redmond-52
# Checking Duplicate: redmond-53
# Checking Duplicate: redmond-44
# 2020425_9-47_20_redmond-49.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-35
# 2020425_9-47_20_redmond-50.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-52.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-37
# 2020425_9-47_20_redmond-35.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-44.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-47.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-53.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-37.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-48
# 2020425_9-47_20_redmond-48.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-57
# 2020425_9-47_20_redmond-57.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-56
# 2020425_9-47_20_redmond-56.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-59
# 2020425_9-47_20_redmond-59.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-61
# 2020425_9-47_21_redmond-61.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-60
# Checking Duplicate: redmond-63
# Checking Duplicate: redmond-62
# 2020425_9-47_21_redmond-63.jpg is a duplicate image.  Removing.
# 2020425_9-47_21_redmond-62.jpg is a duplicate image.  Removing.
# 2020425_9-47_21_redmond-60.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-68
# 2020425_9-47_21_redmond-68.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-27
# 2020425_9-47_19_redmond-27.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-64
# 2020425_9-47_21_redmond-64.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-65
# 2020425_9-47_21_redmond-65.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-67
# 2020425_9-47_21_redmond-67.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-70
# 2020425_9-47_21_redmond-70.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-71
# 2020425_9-47_21_redmond-71.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-72
# 2020425_9-47_21_redmond-72.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-73
# 2020425_9-47_22_redmond-73.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-29
# Checking Duplicate: redmond-66
# 2020425_9-47_19_redmond-29.jpg is a duplicate image.  Removing.
# 2020425_9-47_21_redmond-66.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-74
# 2020425_9-47_22_redmond-74.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-69
# 2020425_9-47_21_redmond-69.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-77
# 2020425_9-47_22_redmond-77.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-85
# Checking Duplicate: redmond-87
# 2020425_9-47_22_redmond-87.jpg is a duplicate image.  Removing.
# 2020425_9-47_22_redmond-85.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-91
# 2020425_9-47_22_redmond-91.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-79
# 2020425_9-47_22_redmond-79.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-83
# Checking Duplicate: redmond-36
# 2020425_9-47_22_redmond-83.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-90
# 2020425_9-47_22_redmond-90.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-36.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-84
# 2020425_9-47_22_redmond-84.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-78
# Checking Duplicate: redmond-76
# 2020425_9-47_22_redmond-78.jpg is a duplicate image.  Removing.
# 2020425_9-47_22_redmond-76.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-99
# Checking Duplicate: redmond-88
# 2020425_9-47_23_redmond-99.jpg is a duplicate image.  Removing.
# 2020425_9-47_22_redmond-88.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-95
# Checking Duplicate: redmond-81
# 2020425_9-47_22_redmond-95.jpg is a duplicate image.  Removing.
# 2020425_9-47_22_redmond-81.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-96
# 2020425_9-47_22_redmond-96.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-92
# 2020425_9-47_22_redmond-92.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-97
# 2020425_9-47_22_redmond-97.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-89
# Checking Duplicate: redmond-93
# 2020425_9-47_22_redmond-89.jpg is a duplicate image.  Removing.
# 2020425_9-47_22_redmond-93.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-82
# 2020425_9-47_22_redmond-82.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-100
# Checking Duplicate: redmond-38
# Checking Duplicate: redmond-98
# 2020425_9-47_23_redmond-100.jpg is a duplicate image.  Removing.
# 2020425_9-47_23_redmond-98.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-94
# 2020425_9-47_22_redmond-94.jpg is a duplicate image.  Removing.
# 2020425_9-47_20_redmond-38.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-86
# 2020425_9-47_22_redmond-86.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-34
# 2020425_9-47_20_redmond-34.jpg is a duplicate image.  Removing.
# Cameras job current time : Sat Apr 25 09:47:39 2020
# Checking Duplicate: redmond-3
# Putting hash 2c32648e393f3f9f0cb6efdebf4f607e for cam redmond-3 in cache.
# Checking Duplicate: redmond-24
# Checking Duplicate: redmond-12
# Checking Duplicate: redmond-30
# Checking Duplicate: redmond-20
# Checking Duplicate: redmond-25
# Checking Duplicate: redmond-16
# Checking Duplicate: redmond-26
# 2020425_9-47_39_redmond-24.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-26.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-16.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-25.jpg is a duplicate image.  Removing.
# Putting hash 243870e4b634e4ae2f3bf0e10000037e for cam redmond-20 in cache.
# Putting hash 6e0d07070b0e170ff4f9ffef7f3efeff for cam redmond-12 in cache.
# Putting hash ced670e0c0c0c0c0c89effe0fb02010c for cam redmond-30 in cache.
# Checking Duplicate: redmond-15
# Checking Duplicate: redmond-28
# Checking Duplicate: redmond-8
# Checking Duplicate: redmond-21
# Checking Duplicate: redmond-5
# Checking Duplicate: redmond-22
# Checking Duplicate: redmond-10
# Checking Duplicate: redmond-4
# 2020425_9-47_39_redmond-8.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-7
# 2020425_9-47_39_redmond-28.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-15.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-22.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-7.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-1
# 2020425_9-47_39_redmond-21.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-5.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-4.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-10.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-1.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-13
# Checking Duplicate: redmond-2
# Checking Duplicate: redmond-14
# Putting hash 0e0f666626e6e6cef3bbff4e3cffe0de for cam redmond-13 in cache.
# 2020425_9-47_39_redmond-2.jpg is a duplicate image.  Removing.
# Putting hash a6be1e1a26eecc9c07fdfc3a77eede10 for cam redmond-14 in cache.
# Checking Duplicate: redmond-9
# Checking Duplicate: redmond-11
# 2020425_9-47_39_redmond-11.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-9.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-18
# 2020425_9-47_39_redmond-18.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-23
# Checking Duplicate: redmond-6
# 2020425_9-47_39_redmond-23.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-6.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-19
# Checking Duplicate: redmond-37
# 2020425_9-47_39_redmond-19.jpg is a duplicate image.  Removing.
# 2020425_9-47_40_redmond-37.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-42
# Checking Duplicate: redmond-31
# 2020425_9-47_40_redmond-42.jpg is a duplicate image.  Removing.
# 2020425_9-47_40_redmond-31.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-17
# 2020425_9-47_39_redmond-17.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-48
# 2020425_9-47_40_redmond-48.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-46
# 2020425_9-47_40_redmond-46.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-32
# Putting hash 886161f1f3e16dbfbc3fcfffe78349ff for cam redmond-32 in cache.
# Checking Duplicate: redmond-33
# Putting hash 92dab43060838a8bfe5ef020e1e66ebf for cam redmond-33 in cache.
# Checking Duplicate: redmond-58
# 2020425_9-47_40_redmond-58.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-40
# Putting hash 18b83838383060c07fffff60f83f61ff for cam redmond-40 in cache.
# Checking Duplicate: redmond-43
# 2020425_9-47_40_redmond-43.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-44
# 2020425_9-47_40_redmond-44.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-50
# 2020425_9-47_40_redmond-50.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-47
# Checking Duplicate: redmond-49
# Checking Duplicate: redmond-54
# Checking Duplicate: redmond-52
# 2020425_9-47_40_redmond-47.jpg is a duplicate image.  Removing.
# 2020425_9-47_40_redmond-54.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-53
# Putting hash a7e66eb3b39c9931ff87dd3aa70800ff for cam redmond-52 in cache.
# Putting hash cec2b2e0f0c088ea0d1e3effff8000fe for cam redmond-49 in cache.
# 2020425_9-47_40_redmond-53.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-35
# 2020425_9-47_40_redmond-35.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-51
# 2020425_9-47_40_redmond-51.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-57
# 2020425_9-47_40_redmond-57.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-55
# Putting hash f0c8c4c5e870fb7cf3d3ff9f1fffe3f0 for cam redmond-55 in cache.
# Checking Duplicate: redmond-56
# 2020425_9-47_40_redmond-56.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-61
# Checking Duplicate: redmond-62
# Checking Duplicate: redmond-27
# 2020425_9-47_41_redmond-61.jpg is a duplicate image.  Removing.
# 2020425_9-47_41_redmond-62.jpg is a duplicate image.  Removing.
# 2020425_9-47_39_redmond-27.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-63
# Checking Duplicate: redmond-64
# 2020425_9-47_41_redmond-63.jpg is a duplicate image.  Removing.
# 2020425_9-47_41_redmond-64.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-65
# 2020425_9-47_41_redmond-65.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-60
# 2020425_9-47_41_redmond-60.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-59
# Checking Duplicate: redmond-67
# Putting hash 585c9e32626202227fff98a1e880007e for cam redmond-59 in cache.
# 2020425_9-47_41_redmond-67.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-70
# Checking Duplicate: redmond-29
# Checking Duplicate: redmond-66
# 2020425_9-47_41_redmond-70.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-71
# Checking Duplicate: redmond-72
# 2020425_9-47_41_redmond-66.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-68
# Putting hash 73f65c7bf6f6df996ba438fbdfe6ceff for cam redmond-71 in cache.
# 2020425_9-47_41_redmond-68.jpg is a duplicate image.  Removing.
# Putting hash cecd8c4fcb8907059f83f06cceb906ff for cam redmond-72 in cache.
# 2020425_9-47_39_redmond-29.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-73
# Putting hash a5e9713169c82080ff08c03f6fdf0080 for cam redmond-73 in cache.
# Checking Duplicate: redmond-74
# Checking Duplicate: redmond-69
# Checking Duplicate: redmond-77
# 2020425_9-47_42_redmond-74.jpg is a duplicate image.  Removing.
# 2020425_9-47_41_redmond-69.jpg is a duplicate image.  Removing.
# 2020425_9-47_42_redmond-77.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-36
# Checking Duplicate: redmond-79
# 2020425_9-47_42_redmond-79.jpg is a duplicate image.  Removing.
# 2020425_9-47_40_redmond-36.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-91
# 2020425_9-47_42_redmond-91.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-88
# 2020425_9-47_42_redmond-88.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-78
# Putting hash 74b2b6f8b2e8e9f871b0ff00f60609fe for cam redmond-78 in cache.
# Checking Duplicate: redmond-87
# 2020425_9-47_42_redmond-87.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-39
# Checking Duplicate: redmond-83
# 2020425_9-47_42_redmond-83.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-76
# Checking Duplicate: redmond-84
# 2020425_9-47_42_redmond-76.jpg is a duplicate image.  Removing.
# 2020425_9-47_42_redmond-84.jpg is a duplicate image.  Removing.
# Putting hash 99b878e8d4b4ececff31644bdff0e3e0 for cam redmond-39 in cache.
# Checking Duplicate: redmond-92
# Putting hash 16b9bda0683933d33efff0ae8ffb0000 for cam redmond-92 in cache.
# Checking Duplicate: redmond-94
# 2020425_9-47_42_redmond-94.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-81
# Checking Duplicate: redmond-89
# 2020425_9-47_42_redmond-81.jpg is a duplicate image.  Removing.
# 2020425_9-47_42_redmond-89.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-38
# Checking Duplicate: redmond-99
# Checking Duplicate: redmond-96
# Putting hash acc6d2e3e8f1e173696cfcc7ffc300ff for cam redmond-99 in cache.
# Putting hash 3efefabdfdb4b43c39fcf2fe59d507fd for cam redmond-96 in cache.
# 2020425_9-47_40_redmond-38.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-93
# 2020425_9-47_42_redmond-93.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-97
# Checking Duplicate: redmond-98
# Checking Duplicate: redmond-90
# Putting hash 1a3e9830f6f2487ad078bf7fffe000ff for cam redmond-97 in cache.
# 2020425_9-47_42_redmond-90.jpg is a duplicate image.  Removing.
# 2020425_9-47_43_redmond-98.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-82
# 2020425_9-47_42_redmond-82.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-95
# Putting hash 3636212034e662c07fb4ffe3748067ff for cam redmond-95 in cache.
# Checking Duplicate: redmond-85
# Checking Duplicate: redmond-100
# Putting hash 9992968ebfbf378ffb3fff8700f8ffff for cam redmond-85 in cache.
# Putting hash 347cfffefadedc9c1721fefc62fec0f9 for cam redmond-100 in cache.
# Checking Duplicate: redmond-86
# 2020425_9-47_42_redmond-86.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-34
# 2020425_9-47_40_redmond-34.jpg is a duplicate image.  Removing.
# Cameras job current time : Sat Apr 25 09:47:59 2020
# Checking Duplicate: redmond-24
# 2020425_9-47_59_redmond-24.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-7
# Checking Duplicate: redmond-14
# 2020425_9-47_59_redmond-7.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-14.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-3
# 2020425_9-47_59_redmond-3.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-4
# 2020425_9-47_59_redmond-4.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-26
# 2020425_9-47_59_redmond-26.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-16
# 2020425_9-47_59_redmond-16.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-20
# Checking Duplicate: redmond-25
# 2020425_9-47_59_redmond-20.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-25.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-12
# Checking Duplicate: redmond-10
# Checking Duplicate: redmond-30
# Checking Duplicate: redmond-15
# Checking Duplicate: redmond-22
# Checking Duplicate: redmond-28
# Checking Duplicate: redmond-21
# Checking Duplicate: redmond-5
# Checking Duplicate: redmond-8
# 2020425_9-47_59_redmond-12.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-15.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-10.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-8.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-30.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-22.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-5.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-21.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-28.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-2
# 2020425_9-47_59_redmond-2.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-13
# Checking Duplicate: redmond-1
# 2020425_9-47_59_redmond-13.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-1.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-11
# Checking Duplicate: redmond-9
# 2020425_9-47_59_redmond-11.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-9.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-6
# Checking Duplicate: redmond-23
# 2020425_9-47_59_redmond-6.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-18
# 2020425_9-47_59_redmond-23.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-18.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-33
# 2020425_9-48_0_redmond-33.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-31
# 2020425_9-48_0_redmond-31.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-17
# 2020425_9-47_59_redmond-17.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-19
# 2020425_9-47_59_redmond-19.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-32
# 2020425_9-48_0_redmond-32.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-46
# 2020425_9-48_0_redmond-46.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-49
# Checking Duplicate: redmond-56
# 2020425_9-48_0_redmond-49.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-56.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-58
# 2020425_9-48_0_redmond-58.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-37
# Checking Duplicate: redmond-40
# 2020425_9-48_0_redmond-37.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-40.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-44
# Checking Duplicate: redmond-43
# 2020425_9-48_0_redmond-43.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-42
# 2020425_9-48_0_redmond-44.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-50
# Checking Duplicate: redmond-47
# 2020425_9-48_0_redmond-50.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-42.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-47.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-54
# Checking Duplicate: redmond-53
# Checking Duplicate: redmond-52
# Checking Duplicate: redmond-35
# 2020425_9-48_0_redmond-54.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-53.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-52.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-35.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-48
# 2020425_9-48_0_redmond-48.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-51
# 2020425_9-48_0_redmond-51.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-55
# Checking Duplicate: redmond-57
# 2020425_9-48_0_redmond-55.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-57.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-59
# 2020425_9-48_0_redmond-59.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-61
# 2020425_9-48_1_redmond-61.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-62
# 2020425_9-48_1_redmond-62.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-60
# 2020425_9-48_1_redmond-60.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-63
# 2020425_9-48_1_redmond-63.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-65
# 2020425_9-48_1_redmond-65.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-27
# Checking Duplicate: redmond-70
# Checking Duplicate: redmond-71
# 2020425_9-48_1_redmond-70.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-64
# 2020425_9-48_1_redmond-71.jpg is a duplicate image.  Removing.
# 2020425_9-48_1_redmond-64.jpg is a duplicate image.  Removing.
# 2020425_9-47_59_redmond-27.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-67
# 2020425_9-48_1_redmond-67.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-76
# Checking Duplicate: redmond-78
# 2020425_9-48_2_redmond-76.jpg is a duplicate image.  Removing.
# 2020425_9-48_2_redmond-78.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-72
# Checking Duplicate: redmond-73
# 2020425_9-48_1_redmond-72.jpg is a duplicate image.  Removing.
# 2020425_9-48_1_redmond-73.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-66
# 2020425_9-48_1_redmond-66.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-68
# 2020425_9-48_1_redmond-68.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-29
# 2020425_9-47_59_redmond-29.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-74
# Checking Duplicate: redmond-83
# 2020425_9-48_1_redmond-74.jpg is a duplicate image.  Removing.
# 2020425_9-48_2_redmond-83.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-69
# 2020425_9-48_1_redmond-69.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-77
# 2020425_9-48_2_redmond-77.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-36
# 2020425_9-48_0_redmond-36.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-79
# 2020425_9-48_2_redmond-79.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-87
# 2020425_9-48_2_redmond-87.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-91
# 2020425_9-48_2_redmond-91.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-39
# Checking Duplicate: redmond-88
# Checking Duplicate: redmond-84
# 2020425_9-48_2_redmond-88.jpg is a duplicate image.  Removing.
# 2020425_9-48_2_redmond-84.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-39.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-89
# 2020425_9-48_2_redmond-89.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-96
# 2020425_9-48_2_redmond-96.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-81
# Checking Duplicate: redmond-93
# Checking Duplicate: redmond-38
# Checking Duplicate: redmond-85
# 2020425_9-48_2_redmond-81.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-99
# 2020425_9-48_2_redmond-93.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-100
# 2020425_9-48_3_redmond-99.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-95
# 2020425_9-48_2_redmond-85.jpg is a duplicate image.  Removing.
# 2020425_9-48_3_redmond-100.jpg is a duplicate image.  Removing.
# 2020425_9-48_2_redmond-95.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-97
# 2020425_9-48_2_redmond-97.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-38.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-92
# Checking Duplicate: redmond-82
# 2020425_9-48_2_redmond-92.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-98
# 2020425_9-48_2_redmond-82.jpg is a duplicate image.  Removing.
# 2020425_9-48_3_redmond-98.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-94
# Checking Duplicate: redmond-90
# 2020425_9-48_2_redmond-94.jpg is a duplicate image.  Removing.
# 2020425_9-48_2_redmond-90.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-34
# Checking Duplicate: redmond-86
# 2020425_9-48_2_redmond-86.jpg is a duplicate image.  Removing.
# 2020425_9-48_0_redmond-34.jpg is a duplicate image.  Removing.
# Cameras job current time : Sat Apr 25 09:48:19 2020
# Checking Duplicate: redmond-11
# Checking Duplicate: redmond-18
# 2020425_9-48_19_redmond-11.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-18.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-3
# Putting hash 6c32609e3f3f3f9f0cbee7c9bc6e607e for cam redmond-3 in cache.
# Checking Duplicate: redmond-20
# Putting hash 243c78e49e448c8e2f3d71e10000037e for cam redmond-20 in cache.
# Checking Duplicate: redmond-25
# Checking Duplicate: redmond-12
# Checking Duplicate: redmond-16
# Checking Duplicate: redmond-30
# 2020425_9-48_19_redmond-12.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-16.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-25.jpg is a duplicate image.  Removing.
# Putting hash ced672e0c0c0c0c0c89cffe01302010e for cam redmond-30 in cache.
# Checking Duplicate: redmond-22
# Checking Duplicate: redmond-10
# Checking Duplicate: redmond-28
# Checking Duplicate: redmond-4
# Checking Duplicate: redmond-5
# Checking Duplicate: redmond-7
# Checking Duplicate: redmond-21
# Checking Duplicate: redmond-15
# Checking Duplicate: redmond-26
# Checking Duplicate: redmond-24
# Checking Duplicate: redmond-8
# 2020425_9-48_19_redmond-7.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-26.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-8.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-28.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-21.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-13
# Putting hash 8f9324632030199cfffffdcfef270000 for cam redmond-22 in cache.
# Checking Duplicate: redmond-1
# Checking Duplicate: redmond-14
# 2020425_9-48_19_redmond-5.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-10.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-24.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-4.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-2
# Putting hash 389a84c0b111d8fcfffbbcdf0302137c for cam redmond-15 in cache.
# 2020425_9-48_19_redmond-2.jpg is a duplicate image.  Removing.
# 2020425_9-48_19_redmond-1.jpg is a duplicate image.  Removing.
# Putting hash 160f666626e6e6cef3bbdf4e3cfee0de for cam redmond-13 in cache.
# Putting hash a6be1e1a26eecc9407ecfc3876eede10 for cam redmond-14 in cache.
# Checking Duplicate: redmond-9
# 2020425_9-48_19_redmond-9.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-6
# Putting hash 2010d4c6a4068082040371fba000003e for cam redmond-6 in cache.
# Checking Duplicate: redmond-23
# 2020425_9-48_19_redmond-23.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-32
# 2020425_9-48_20_redmond-32.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-33
# 2020425_9-48_20_redmond-33.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-19
# 2020425_9-48_19_redmond-19.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-31
# 2020425_9-48_20_redmond-31.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-17
# 2020425_9-48_19_redmond-17.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-46
# 2020425_9-48_20_redmond-46.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-53
# 2020425_9-48_20_redmond-53.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-38
# 2020425_9-48_20_redmond-38.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-58
# 2020425_9-48_20_redmond-58.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-37
# Checking Duplicate: redmond-49
# Checking Duplicate: redmond-54
# 2020425_9-48_20_redmond-37.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-40
# 2020425_9-48_20_redmond-54.jpg is a duplicate image.  Removing.
# Putting hash c6f6b2e0f0c088ea0f063efff78000fe for cam redmond-49 in cache.
# 2020425_9-48_20_redmond-40.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-43
# Checking Duplicate: redmond-44
# Checking Duplicate: redmond-47
# 2020425_9-48_20_redmond-44.jpg is a duplicate image.  Removing.
# Putting hash d9d8ca8f8f07035bfff1c0f9e80c0e76 for cam redmond-43 in cache.
# Putting hash b3f7f07074f0f2d3273fbfa3e1ef7efe for cam redmond-47 in cache.
# Checking Duplicate: redmond-50
# Checking Duplicate: redmond-51
# Checking Duplicate: redmond-52
# 2020425_9-48_20_redmond-50.jpg is a duplicate image.  Removing.
# Putting hash 78f8f8f87c78f9fa7d00f18700f8fff8 for cam redmond-51 in cache.
# Checking Duplicate: redmond-61
# Putting hash a7e66ebba38c9911ff87cd3a87ec983f for cam redmond-52 in cache.
# Checking Duplicate: redmond-42
# 2020425_9-48_20_redmond-42.jpg is a duplicate image.  Removing.
# 2020425_9-48_21_redmond-61.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-48
# Checking Duplicate: redmond-35
# 2020425_9-48_20_redmond-48.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-57
# 2020425_9-48_20_redmond-35.jpg is a duplicate image.  Removing.
# 2020425_9-48_20_redmond-57.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-56
# Checking Duplicate: redmond-60
# 2020425_9-48_21_redmond-60.jpg is a duplicate image.  Removing.
# Putting hash e3a1b3e3c1a968c3de3f77fc8613fcee for cam redmond-56 in cache.
# Checking Duplicate: redmond-55
# 2020425_9-48_20_redmond-55.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-63
# 2020425_9-48_21_redmond-63.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-59
# Putting hash 58589eb0626202227fff98a1f880007e for cam redmond-59 in cache.
# Checking Duplicate: redmond-62
# Putting hash 839d8e829d3727daef1101069f306fff for cam redmond-62 in cache.
# Checking Duplicate: redmond-27
# 2020425_9-48_19_redmond-27.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-65
# 2020425_9-48_21_redmond-65.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-64
# 2020425_9-48_21_redmond-64.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-69
# 2020425_9-48_21_redmond-69.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-67
# 2020425_9-48_21_redmond-67.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-71
# Checking Duplicate: redmond-70
# Checking Duplicate: redmond-72
# Putting hash 72f67c7bf6f6df996b8478fbdfe6ceff for cam redmond-71 in cache.
# Checking Duplicate: redmond-66
# Putting hash 63e02cfcfeffecfeffc73f05f8fcaffe for cam redmond-70 in cache.
# Checking Duplicate: redmond-29
# 2020425_9-48_21_redmond-66.jpg is a duplicate image.  Removing.
# 2020425_9-48_22_redmond-72.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-68
# Checking Duplicate: redmond-73
# 2020425_9-48_21_redmond-68.jpg is a duplicate image.  Removing.
# Putting hash a1e8711169d830c0ff08c03f6fff0080 for cam redmond-73 in cache.
# 2020425_9-48_19_redmond-29.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-87
# Checking Duplicate: redmond-74
# 2020425_9-48_22_redmond-87.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-77
# 2020425_9-48_22_redmond-74.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-91
# 2020425_9-48_22_redmond-77.jpg is a duplicate image.  Removing.
# 2020425_9-48_22_redmond-91.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-36
# 2020425_9-48_20_redmond-36.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-88
# Putting hash 9efebebf92e2eada1f7ce0fe3f000000 for cam redmond-88 in cache.
# Checking Duplicate: redmond-79
# 2020425_9-48_22_redmond-79.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-83
# Checking Duplicate: redmond-84
# 2020425_9-48_22_redmond-84.jpg is a duplicate image.  Removing.
# 2020425_9-48_22_redmond-83.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-78
# Putting hash f4b2f6b8b2e8e9f87120ff00f60609ff for cam redmond-78 in cache.
# Checking Duplicate: redmond-89
# 2020425_9-48_22_redmond-89.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-76
# 2020425_9-48_22_redmond-76.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-39
# Checking Duplicate: redmond-92
# Checking Duplicate: redmond-99
# Putting hash 16b9b3a16427270f3ef9f2a28fff0000 for cam redmond-92 in cache.
# 2020425_9-48_20_redmond-39.jpg is a duplicate image.  Removing.
# Putting hash ace6d2e3e0f1a063696cf4d7ffc100ff for cam redmond-99 in cache.
# Checking Duplicate: redmond-95
# Checking Duplicate: redmond-81
# Checking Duplicate: redmond-93
# Checking Duplicate: redmond-90
# Putting hash 3636212034e663c05fb4ff8374946fff for cam redmond-95 in cache.
# Checking Duplicate: redmond-85
# 2020425_9-48_22_redmond-81.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-96
# Putting hash b2ff77dd5f9f9c1967fe62fde6ff8000 for cam redmond-93 in cache.
# 2020425_9-48_22_redmond-90.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-98
# Putting hash 3efefab9fdb5b4b439fcf2ff5995bffd for cam redmond-96 in cache.
# Checking Duplicate: redmond-100
# 2020425_9-48_22_redmond-85.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-94
# Putting hash 6666fae0c0d28808070cfeffc5c0803f for cam redmond-98 in cache.
# 2020425_9-48_22_redmond-94.jpg is a duplicate image.  Removing.
# 2020425_9-48_23_redmond-100.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-86
# 2020425_9-48_22_redmond-86.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-82
# Checking Duplicate: redmond-97
# Putting hash 183e9834f6f24877d178bf7fffe001ff for cam redmond-97 in cache.
# Putting hash e8f8f2e8e9e9d8f07fdff0c3f7ec5e38 for cam redmond-82 in cache.
# Checking Duplicate: redmond-34
# 2020425_9-48_20_redmond-34.jpg is a duplicate image.  Removing.
# Cameras job current time : Sat Apr 25 09:48:39 2020
# Checking Duplicate: redmond-3
# 2020425_9-48_39_redmond-3.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-25
# Checking Duplicate: redmond-20
# Checking Duplicate: redmond-16
# Checking Duplicate: redmond-12
# 2020425_9-48_39_redmond-25.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-24
# Checking Duplicate: redmond-26
# 2020425_9-48_39_redmond-12.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-22
# 2020425_9-48_39_redmond-20.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-16.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-26.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-24.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-22.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-1
# 2020425_9-48_39_redmond-1.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-28
# Checking Duplicate: redmond-8
# Checking Duplicate: redmond-21
# Checking Duplicate: redmond-15
# Checking Duplicate: redmond-10
# Checking Duplicate: redmond-5
# Checking Duplicate: redmond-30
# 2020425_9-48_39_redmond-28.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-10.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-5.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-15.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-8.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-21.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-30.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-13
# 2020425_9-48_39_redmond-13.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-14
# Checking Duplicate: redmond-7
# 2020425_9-48_39_redmond-14.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-7.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-4
# Checking Duplicate: redmond-11
# Checking Duplicate: redmond-2
# 2020425_9-48_39_redmond-4.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-2.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-11.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-9
# 2020425_9-48_39_redmond-9.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-6
# Checking Duplicate: redmond-23
# Checking Duplicate: redmond-18
# 2020425_9-48_39_redmond-6.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-23.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-18.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-33
# 2020425_9-48_40_redmond-33.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-31
# 2020425_9-48_40_redmond-31.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-49
# 2020425_9-48_40_redmond-49.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-19
# 2020425_9-48_39_redmond-19.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-50
# 2020425_9-48_40_redmond-50.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-46
# 2020425_9-48_40_redmond-46.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-17
# 2020425_9-48_39_redmond-17.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-36
# 2020425_9-48_40_redmond-36.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-32
# 2020425_9-48_40_redmond-32.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-38
# 2020425_9-48_40_redmond-38.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-58
# Checking Duplicate: redmond-40
# Checking Duplicate: redmond-54
# 2020425_9-48_40_redmond-58.jpg is a duplicate image.  Removing.
# 2020425_9-48_40_redmond-40.jpg is a duplicate image.  Removing.
# 2020425_9-48_40_redmond-54.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-42
# 2020425_9-48_40_redmond-42.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-37
# 2020425_9-48_40_redmond-37.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-43
# Checking Duplicate: redmond-44
# Checking Duplicate: redmond-47
# 2020425_9-48_40_redmond-43.jpg is a duplicate image.  Removing.
# 2020425_9-48_40_redmond-44.jpg is a duplicate image.  Removing.
# 2020425_9-48_40_redmond-47.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-52
# 2020425_9-48_40_redmond-52.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-53
# 2020425_9-48_40_redmond-53.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-48
# 2020425_9-48_40_redmond-48.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-51
# 2020425_9-48_40_redmond-51.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-60
# 2020425_9-48_41_redmond-60.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-35
# 2020425_9-48_40_redmond-35.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-57
# Checking Duplicate: redmond-62
# 2020425_9-48_40_redmond-57.jpg is a duplicate image.  Removing.
# 2020425_9-48_41_redmond-62.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-55
# Checking Duplicate: redmond-56
# Checking Duplicate: redmond-61
# 2020425_9-48_40_redmond-55.jpg is a duplicate image.  Removing.
# 2020425_9-48_40_redmond-56.jpg is a duplicate image.  Removing.
# 2020425_9-48_41_redmond-61.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-63
# 2020425_9-48_41_redmond-63.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-64
# 2020425_9-48_41_redmond-64.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-65
# 2020425_9-48_41_redmond-65.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-59
# Checking Duplicate: redmond-27
# 2020425_9-48_41_redmond-59.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-27.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-67
# 2020425_9-48_41_redmond-67.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-66
# 2020425_9-48_41_redmond-66.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-78
# Checking Duplicate: redmond-79
# 2020425_9-48_41_redmond-78.jpg is a duplicate image.  Removing.
# 2020425_9-48_41_redmond-79.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-71
# Checking Duplicate: redmond-70
# 2020425_9-48_41_redmond-71.jpg is a duplicate image.  Removing.
# 2020425_9-48_41_redmond-70.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-72
# Checking Duplicate: redmond-73
# 2020425_9-48_41_redmond-72.jpg is a duplicate image.  Removing.
# 2020425_9-48_41_redmond-73.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-68
# 2020425_9-48_41_redmond-68.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-29
# Checking Duplicate: redmond-74
# 2020425_9-48_41_redmond-74.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-77
# 2020425_9-48_41_redmond-77.jpg is a duplicate image.  Removing.
# 2020425_9-48_39_redmond-29.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-69
# 2020425_9-48_41_redmond-69.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-91
# 2020425_9-48_42_redmond-91.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-87
# 2020425_9-48_42_redmond-87.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-88
# Checking Duplicate: redmond-83
# 2020425_9-48_42_redmond-88.jpg is a duplicate image.  Removing.
# 2020425_9-48_42_redmond-83.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-39
# Checking Duplicate: redmond-84
# 2020425_9-48_42_redmond-84.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-76
# 2020425_9-48_41_redmond-76.jpg is a duplicate image.  Removing.
# 2020425_9-48_40_redmond-39.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-94
# Checking Duplicate: redmond-89
# 2020425_9-48_42_redmond-94.jpg is a duplicate image.  Removing.
# 2020425_9-48_42_redmond-89.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-96
# 2020425_9-48_42_redmond-96.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-92
# 2020425_9-48_42_redmond-92.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-99
# 2020425_9-48_42_redmond-99.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-81
# 2020425_9-48_42_redmond-81.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-85
# 2020425_9-48_42_redmond-85.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-90
# Checking Duplicate: redmond-98
# Checking Duplicate: redmond-97
# 2020425_9-48_42_redmond-98.jpg is a duplicate image.  Removing.
# 2020425_9-48_42_redmond-97.jpg is a duplicate image.  Removing.
# 2020425_9-48_42_redmond-90.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-95
# 2020425_9-48_42_redmond-95.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-93
# Checking Duplicate: redmond-100
# 2020425_9-48_42_redmond-93.jpg is a duplicate image.  Removing.
# 2020425_9-48_42_redmond-100.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-82
# 2020425_9-48_42_redmond-82.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-86
# 2020425_9-48_42_redmond-86.jpg is a duplicate image.  Removing.
# Checking Duplicate: redmond-34
# 2020425_9-48_40_redmond-34.jpg is a duplicate image.  Removing.
